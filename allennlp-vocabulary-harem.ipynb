# %% [markdown]
# ## IMDb

# %% [markdown]
# At Fast.ai we have introduced a new module called fastai.text which replaces the torchtext library that was used in our 2018 dl1 course. The fastai.text module also supersedes the fastai.nlp library but retains many of the key functions.

# %%
from fastai.text import *
from fastai.core import num_cpus, partition_by_cores
import html
from pathlib import Path
import numpy as np
import csv
import pandas as pd
from collections import Counter, defaultdict
from itertools import chain
from nltk.corpus import brown
import os, re

from gensim.corpora import Dictionary
from gensim.models import Word2Vec
from typing import Callable, List, Collection
from concurrent.futures.process import ProcessPoolExecutor

# %% [markdown]
# The Fastai.text module introduces several custom tokens.
#
# We need to download the IMDB large movie reviews from this site: http://ai.stanford.edu/~amaas/data/sentiment/
# Direct link : [Link](http://ai.stanford.edu/~amaas/data/sentiment/aclImdb_v1.tar.gz) and untar it into the PATH location. We use pathlib which makes directory traveral a breeze.

# %%
PATH=Path('/media/discoD/repositorios/1-billion-word-language-modeling-benchmark/')

# %% [markdown]
# ## Standardize format

# %% [markdown]
# The imdb dataset has 3 classes. positive, negative and unsupervised(sentiment is unknown).
# There are 75k training reviews(12.5k pos, 12.5k neg, 50k unsup)
# There are 25k validation reviews(12.5k pos, 12.5k neg & no unsup)
#
# Refer to the README file in the imdb corpus for further information about the dataset.

# %%
class VocabularyTokenizer():
    "Put together rules, a tokenizer function and a language to tokenize text with multiprocessing."
    def __init__(self, tok_func:Callable=SpacyTokenizer, lang:str='pt', n_cpus:int=None):
        self.tok_func,self.lang = tok_func,lang
        self.n_cpus = n_cpus or num_cpus()//2

    def process_text(self, t:str, tok:BaseTokenizer) -> List[str]:
        "Processe one text `t` with tokenizer `tok`."
        return tok.tokenizer(t)

    def _process_all_1(self, texts:Collection[str]) -> List[List[str]]:
        "Process a list of `texts` in one process."
        tok = self.tok_func(self.lang)
        return [self.process_text(t, tok) for t in texts]

    def process_all(self, texts:Collection[str]) -> List[List[str]]:
        "Process a list of `texts`."
        if self.n_cpus <= 1: return self._process_all_1(texts)
        with ProcessPoolExecutor(self.n_cpus) as e:
            return sum(e.map(self._process_all_1, partition_by_cores(texts, self.n_cpus)), [])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-81c28dabd338> in <module>
# ----> 1 class VocabularyTokenizer():
#       2     "Put together rules, a tokenizer function and a language to tokenize text with multiprocessing."
#       3     def __init__(self, tok_func:Callable=SpacyTokenizer, lang:str='pt', n_cpus:int=None):
#       4         self.tok_func,self.lang = tok_func,lang
#       5         self.n_cpus = n_cpus or num_cpus()//2
#
# <ipython-input-1-81c28dabd338> in VocabularyTokenizer()
#       1 class VocabularyTokenizer():
#       2     "Put together rules, a tokenizer function and a language to tokenize text with multiprocessing."
# ----> 3     def __init__(self, tok_func:Callable=SpacyTokenizer, lang:str='pt', n_cpus:int=None):
#       4         self.tok_func,self.lang = tok_func,lang
#       5         self.n_cpus = n_cpus or num_cpus()//2
#
# NameError: name 'SpacyTokenizer' is not defined

# %%
def save_texts(paths, filename, lang):
    CLASSES = ['unsup']
    file_count = 0
    filename = filename + '_' + lang + '.csv'
    if os.path.isfile(filename):
        os.remove(filename)
    with open(filename, 'a') as csvfile:
        writer = csv.writer(csvfile, delimiter=',', quoting=csv.QUOTE_NONE, escapechar='\\')
        for idx,label in enumerate(CLASSES):
            for path in paths:
                for fname in (path).glob('*'):
                    file_count += 1
                    print('writing from %s' % fname)
                    [writer.writerow([line, idx]) for line in fname.open('r', encoding='utf-8').read().split('\n')]
    print('%d texts saved to %s' % (file_count, filename))

# %%
save_texts([PATH/'training-harem/'], 'train_harem', 'pt')
save_texts([PATH/'heldout-harem/'], 'test_harem', 'pt')
save_texts([PATH/'training-harem/',PATH/'heldout-harem/'], 'full_harem', 'pt')
# Out:
# writing from /media/discoD/repositorios/1-billion-word-language-modeling-benchmark/training-harem/harem-00001-of-00100
# writing from /media/discoD/repositorios/1-billion-word-language-modeling-benchmark/training-harem/harem-00002-of-00100
# writing from /media/discoD/repositorios/1-billion-word-language-modeling-benchmark/training-harem/harem-00003-of-00100
# writing from /media/discoD/repositorios/1-billion-word-language-modeling-benchmark/training-harem/harem-00004-of-00100
# writing from /media/discoD/repositorios/1-billion-word-language-modeling-benchmark/training-harem/harem-00005-of-00100
# writing from /media/discoD/repositorios/1-billion-word-language-modeling-benchmark/training-harem/harem-00006-of-00100
# writing from /media/discoD/repositorios/1-billion-word-language-modeling-benchmark/training-harem/harem-00007-of-00100
# writing from /media/discoD/repositorios/1-billion-word-language-modeling-benchmark/training-harem/harem-00008-of-00100
# writing from /media/discoD/repositorios/1-billion-word-language-modeling-benchmark/training-harem/harem-00009-of-00100
# writing from /media/discoD/repositorios/1-billion-word-language-modeling-benchmark/training-harem/harem-00010-of-00100
# writing from /media/discoD/repositorios/1-billion-word-language-modeling-benchmark/training-harem/harem-00011-of-00100
# writing from /media/discoD/repositorios/1-billion-word-language-modeling-benchmark/training-harem/harem-00012-of-00100
# writing from /media/discoD/repositorios/1-billion-word-language-modeling-benchmark/training-harem/harem-00013-of-00100
# writing from /media/discoD/repositorios/1-billion-word-language-modeling-benchmark/training-harem/harem-00014-of-00100
# writing from /media/discoD/repositorios/1-billion-word-language-modeling-benchmark/training-harem/harem-00016-of-00100
# writing from /media/discoD/repositorios/1-billion-word-language-modeling-benchmark/training-harem/harem-00017-of-00100
# writing from /media/discoD/repositorios/1-billion-word-language-modeling-benchmark/training-harem/harem-00018-of-00100
# writing from /media/discoD/repositorios/1-billion-word-language-modeling-benchmark/training-harem/harem-00019-of-00100
# writing from /media/discoD/repositorios/1-billion-word-language-modeling-benchmark/training-harem/harem-00020-of-00100
# writing from /media/discoD/repositorios/1-billion-word-language-modeling-benchmark/training-harem/harem-00021-of-00100
# writing from /media/discoD/repositorios/1-billion-word-language-modeling-benchmark/training-harem/harem-00022-of-00100
# writing from /media/discoD/repositorios/1-billion-word-language-modeling-benchmark/training-harem/harem-00023-of-00100
# writing from /media/discoD/repositorios/1-billion-word-language-modeling-benchmark/training-harem/harem-00024-of-00100
# writing from /media/discoD/repositorios/1-billion-word-language-modeling-benchmark/training-harem/harem-00025-of-00100
# writing from /media/discoD/repositorios/1-billion-word-language-modeling-benchmark/training-harem/harem-00026-of-00100
# writing from /media/discoD/repositorios/1-billion-word-language-modeling-benchmark/training-harem/harem-00027-of-00100
# writing from /media/discoD/repositorios/1-billion-word-language-modeling-benchmark/training-harem/harem-00028-of-00100
# writing from /media/discoD/repositorios/1-billion-word-language-modeling-benchmark/training-harem/harem-00029-of-00100
# writing from /media/discoD/repositorios/1-billion-word-language-modeling-benchmark/training-harem/harem-00030-of-00100
# writing from /media/discoD/repositorios/1-billion-word-language-modeling-benchmark/training-harem/harem-00032-of-00100
# writing from /media/discoD/repositorios/1-billion-word-language-modeling-benchmark/training-harem/harem-00033-of-00100
# writing from /media/discoD/repositorios/1-billion-word-language-modeling-benchmark/training-harem/harem-00034-of-00100
# writing from /media/discoD/repositorios/1-billion-word-language-modeling-benchmark/training-harem/harem-00035-of-00100
# writing from /media/discoD/repositorios/1-billion-word-language-modeling-benchmark/training-harem/harem-00036-of-00100
# writing from /media/discoD/repositorios/1-billion-word-language-modeling-benchmark/training-harem/harem-00037-of-00100
# writing from /media/discoD/repositorios/1-billion-word-language-modeling-benchmark/training-harem/harem-00038-of-00100
# writing from /media/discoD/repositorios/1-billion-word-language-modeling-benchmark/training-harem/harem-00039-of-00100
# writing from /media/discoD/repositorios/1-billion-word-language-modeling-benchmark/training-harem/harem-00040-of-00100
# writing from /media/discoD/repositorios/1-billion-word-language-modeling-benchmark/training-harem/harem-00041-of-00100
# writing from /media/discoD/repositorios/1-billion-word-language-modeling-benchmark/training-harem/harem-00042-of-00100
# writing from /media/discoD/repositorios/1-billion-word-language-modeling-benchmark/training-harem/harem-00043-of-00100
# writing from /media/discoD/repositorios/1-billion-word-language-modeling-benchmark/training-harem/harem-00044-of-00100
# writing from /media/discoD/repositorios/1-billion-word-language-modeling-benchmark/training-harem/harem-00045-of-00100
# writing from /media/discoD/repositorios/1-billion-word-language-modeling-benchmark/training-harem/harem-00046-of-00100
# writing from /media/discoD/repositorios/1-billion-word-language-modeling-benchmark/training-harem/harem-00048-of-00100
# writing from /media/discoD/repositorios/1-billion-word-language-modeling-benchmark/training-harem/harem-00049-of-00100
# writing from /media/discoD/repositorios/1-billion-word-language-modeling-benchmark/training-harem/harem-00050-of-00100
# writing from /media/discoD/repositorios/1-billion-word-language-modeling-benchmark/training-harem/harem-00051-of-00100
# writing from /media/discoD/repositorios/1-billion-word-language-modeling-benchmark/training-harem/harem-00052-of-00100
# writing from /media/discoD/repositorios/1-billion-word-language-modeling-benchmark/training-harem/harem-00053-of-00100
# writing from /media/discoD/repositorios/1-billion-word-language-modeling-benchmark/training-harem/harem-00054-of-00100
# writing from /media/discoD/repositorios/1-billion-word-language-modeling-benchmark/training-harem/harem-00055-of-00100
# writing from /media/discoD/repositorios/1-billion-word-language-modeling-benchmark/training-harem/harem-00056-of-00100
# writing from /media/discoD/repositorios/1-billion-word-language-modeling-benchmark/training-harem/harem-00057-of-00100
# writing from /media/discoD/repositorios/1-billion-word-language-modeling-benchmark/training-harem/harem-00058-of-00100
# writing from /media/discoD/repositorios/1-billion-word-language-modeling-benchmark/training-harem/harem-00059-of-00100
# writing from /media/discoD/repositorios/1-billion-word-language-modeling-benchmark/training-harem/harem-00060-of-00100
# writing from /media/discoD/repositorios/1-billion-word-language-modeling-benchmark/training-harem/harem-00061-of-00100
# writing from /media/discoD/repositorios/1-billion-word-language-modeling-benchmark/training-harem/harem-00062-of-00100
# writing from /media/discoD/repositorios/1-billion-word-language-modeling-benchmark/training-harem/harem-00015-of-00100
# writing from /media/discoD/repositorios/1-billion-word-language-modeling-benchmark/training-harem/harem-00031-of-00100
# writing from /media/discoD/repositorios/1-billion-word-language-modeling-benchmark/training-harem/harem-00047-of-00100
# writing from /media/discoD/repositorios/1-billion-word-language-modeling-benchmark/training-harem/harem-00063-of-00100
# writing from /media/discoD/repositorios/1-billion-word-language-modeling-benchmark/training-harem/harem-00079-of-00100
# writing from /media/discoD/repositorios/1-billion-word-language-modeling-benchmark/training-harem/harem-00064-of-00100
# writing from /media/discoD/repositorios/1-billion-word-language-modeling-benchmark/training-harem/harem-00065-of-00100
# writing from /media/discoD/repositorios/1-billion-word-language-modeling-benchmark/training-harem/harem-00066-of-00100
# writing from /media/discoD/repositorios/1-billion-word-language-modeling-benchmark/training-harem/harem-00067-of-00100
# writing from /media/discoD/repositorios/1-billion-word-language-modeling-benchmark/training-harem/harem-00068-of-00100
# writing from /media/discoD/repositorios/1-billion-word-language-modeling-benchmark/training-harem/harem-00069-of-00100
# writing from /media/discoD/repositorios/1-billion-word-language-modeling-benchmark/training-harem/harem-00070-of-00100
# writing from /media/discoD/repositorios/1-billion-word-language-modeling-benchmark/training-harem/harem-00071-of-00100
# writing from /media/discoD/repositorios/1-billion-word-language-modeling-benchmark/training-harem/harem-00072-of-00100
# writing from /media/discoD/repositorios/1-billion-word-language-modeling-benchmark/training-harem/harem-00073-of-00100
# writing from /media/discoD/repositorios/1-billion-word-language-modeling-benchmark/training-harem/harem-00074-of-00100
# writing from /media/discoD/repositorios/1-billion-word-language-modeling-benchmark/training-harem/harem-00075-of-00100
# writing from /media/discoD/repositorios/1-billion-word-language-modeling-benchmark/training-harem/harem-00076-of-00100
# writing from /media/discoD/repositorios/1-billion-word-language-modeling-benchmark/training-harem/harem-00077-of-00100
# writing from /media/discoD/repositorios/1-billion-word-language-modeling-benchmark/training-harem/harem-00078-of-00100
# writing from /media/discoD/repositorios/1-billion-word-language-modeling-benchmark/training-harem/harem-00080-of-00100
# writing from /media/discoD/repositorios/1-billion-word-language-modeling-benchmark/training-harem/harem-00081-of-00100
# writing from /media/discoD/repositorios/1-billion-word-language-modeling-benchmark/training-harem/harem-00082-of-00100
# writing from /media/discoD/repositorios/1-billion-word-language-modeling-benchmark/training-harem/harem-00083-of-00100
# writing from /media/discoD/repositorios/1-billion-word-language-modeling-benchmark/training-harem/harem-00084-of-00100
# writing from /media/discoD/repositorios/1-billion-word-language-modeling-benchmark/training-harem/harem-00085-of-00100
# writing from /media/discoD/repositorios/1-billion-word-language-modeling-benchmark/training-harem/harem-00086-of-00100
# writing from /media/discoD/repositorios/1-billion-word-language-modeling-benchmark/training-harem/harem-00087-of-00100
# writing from /media/discoD/repositorios/1-billion-word-language-modeling-benchmark/training-harem/harem-00088-of-00100
# writing from /media/discoD/repositorios/1-billion-word-language-modeling-benchmark/training-harem/harem-00089-of-00100
# writing from /media/discoD/repositorios/1-billion-word-language-modeling-benchmark/training-harem/harem-00090-of-00100
# writing from /media/discoD/repositorios/1-billion-word-language-modeling-benchmark/training-harem/harem-00091-of-00100
# writing from /media/discoD/repositorios/1-billion-word-language-modeling-benchmark/training-harem/harem-00092-of-00100
# writing from /media/discoD/repositorios/1-billion-word-language-modeling-benchmark/training-harem/harem-00093-of-00100
# writing from /media/discoD/repositorios/1-billion-word-language-modeling-benchmark/training-harem/harem-00094-of-00100
# writing from /media/discoD/repositorios/1-billion-word-language-modeling-benchmark/training-harem/harem-00095-of-00100
# writing from /media/discoD/repositorios/1-billion-word-language-modeling-benchmark/training-harem/harem-00096-of-00100
# writing from /media/discoD/repositorios/1-billion-word-language-modeling-benchmark/training-harem/harem-00097-of-00100
# writing from /media/discoD/repositorios/1-billion-word-language-modeling-benchmark/training-harem/harem-00098-of-00100
# writing from /media/discoD/repositorios/1-billion-word-language-modeling-benchmark/training-harem/harem-00099-of-00100
# 99 texts saved to train_harem_pt.csv
# writing from /media/discoD/repositorios/1-billion-word-language-modeling-benchmark/heldout-harem/harem.heldout-00013-of-00050
# writing from /media/discoD/repositorios/1-billion-word-language-modeling-benchmark/heldout-harem/harem.heldout-00027-of-00050
# writing from /media/discoD/repositorios/1-billion-word-language-modeling-benchmark/heldout-harem/harem-00000-of-00100
# writing from /media/discoD/repositorios/1-billion-word-language-modeling-benchmark/heldout-harem/harem.heldout-00000-of-00050
# writing from /media/discoD/repositorios/1-billion-word-language-modeling-benchmark/heldout-harem/harem.heldout-00001-of-00050
# writing from /media/discoD/repositorios/1-billion-word-language-modeling-benchmark/heldout-harem/harem.heldout-00002-of-00050
# writing from /media/discoD/repositorios/1-billion-word-language-modeling-benchmark/heldout-harem/harem.heldout-00003-of-00050
# writing from /media/discoD/repositorios/1-billion-word-language-modeling-benchmark/heldout-harem/harem.heldout-00004-of-00050
# writing from /media/discoD/repositorios/1-billion-word-language-modeling-benchmark/heldout-harem/harem.heldout-00005-of-00050
# writing from /media/discoD/repositorios/1-billion-word-language-modeling-benchmark/heldout-harem/harem.heldout-00006-of-00050
# writing from /media/discoD/repositorios/1-billion-word-language-modeling-benchmark/heldout-harem/harem.heldout-00007-of-00050
# writing from /media/discoD/repositorios/1-billion-word-language-modeling-benchmark/heldout-harem/harem.heldout-00008-of-00050
# writing from /media/discoD/repositorios/1-billion-word-language-modeling-benchmark/heldout-harem/harem.heldout-00009-of-00050
# writing from /media/discoD/repositorios/1-billion-word-language-modeling-benchmark/heldout-harem/harem.heldout-00010-of-00050
# writing from /media/discoD/repositorios/1-billion-word-language-modeling-benchmark/heldout-harem/harem.heldout-00011-of-00050
# writing from /media/discoD/repositorios/1-billion-word-language-modeling-benchmark/heldout-harem/harem.heldout-00012-of-00050
# writing from /media/discoD/repositorios/1-billion-word-language-modeling-benchmark/heldout-harem/harem.heldout-00014-of-00050
# writing from /media/discoD/repositorios/1-billion-word-language-modeling-benchmark/heldout-harem/harem.heldout-00015-of-00050
# writing from /media/discoD/repositorios/1-billion-word-language-modeling-benchmark/heldout-harem/harem.heldout-00016-of-00050
# writing from /media/discoD/repositorios/1-billion-word-language-modeling-benchmark/heldout-harem/harem.heldout-00017-of-00050
# writing from /media/discoD/repositorios/1-billion-word-language-modeling-benchmark/heldout-harem/harem.heldout-00018-of-00050
# writing from /media/discoD/repositorios/1-billion-word-language-modeling-benchmark/heldout-harem/harem.heldout-00019-of-00050
# writing from /media/discoD/repositorios/1-billion-word-language-modeling-benchmark/heldout-harem/harem.heldout-00020-of-00050
# writing from /media/discoD/repositorios/1-billion-word-language-modeling-benchmark/heldout-harem/harem.heldout-00021-of-00050
# writing from /media/discoD/repositorios/1-billion-word-language-modeling-benchmark/heldout-harem/harem.heldout-00022-of-00050
# writing from /media/discoD/repositorios/1-billion-word-language-modeling-benchmark/heldout-harem/harem.heldout-00023-of-00050
# writing from /media/discoD/repositorios/1-billion-word-language-modeling-benchmark/heldout-harem/harem.heldout-00024-of-00050
# writing from /media/discoD/repositorios/1-billion-word-language-modeling-benchmark/heldout-harem/harem.heldout-00025-of-00050
# writing from /media/discoD/repositorios/1-billion-word-language-modeling-benchmark/heldout-harem/harem.heldout-00026-of-00050
# writing from /media/discoD/repositorios/1-billion-word-language-modeling-benchmark/heldout-harem/harem.heldout-00028-of-00050
# writing from /media/discoD/repositorios/1-billion-word-language-modeling-benchmark/heldout-harem/harem.heldout-00029-of-00050
# writing from /media/discoD/repositorios/1-billion-word-language-modeling-benchmark/heldout-harem/harem.heldout-00030-of-00050
# writing from /media/discoD/repositorios/1-billion-word-language-modeling-benchmark/heldout-harem/harem.heldout-00031-of-00050
# writing from /media/discoD/repositorios/1-billion-word-language-modeling-benchmark/heldout-harem/harem.heldout-00032-of-00050
# writing from /media/discoD/repositorios/1-billion-word-language-modeling-benchmark/heldout-harem/harem.heldout-00033-of-00050
# writing from /media/discoD/repositorios/1-billion-word-language-modeling-benchmark/heldout-harem/harem.heldout-00034-of-00050
# writing from /media/discoD/repositorios/1-billion-word-language-modeling-benchmark/heldout-harem/harem.heldout-00035-of-00050
# writing from /media/discoD/repositorios/1-billion-word-language-modeling-benchmark/heldout-harem/harem.heldout-00036-of-00050
# writing from /media/discoD/repositorios/1-billion-word-language-modeling-benchmark/heldout-harem/harem.heldout-00037-of-00050
# writing from /media/discoD/repositorios/1-billion-word-language-modeling-benchmark/heldout-harem/harem.heldout-00038-of-00050
# writing from /media/discoD/repositorios/1-billion-word-language-modeling-benchmark/heldout-harem/harem.heldout-00039-of-00050
# writing from /media/discoD/repositorios/1-billion-word-language-modeling-benchmark/heldout-harem/harem.heldout-00040-of-00050
# writing from /media/discoD/repositorios/1-billion-word-language-modeling-benchmark/heldout-harem/harem.heldout-00041-of-00050
# writing from /media/discoD/repositorios/1-billion-word-language-modeling-benchmark/heldout-harem/harem.heldout-00042-of-00050
# writing from /media/discoD/repositorios/1-billion-word-language-modeling-benchmark/heldout-harem/harem.heldout-00043-of-00050
# writing from /media/discoD/repositorios/1-billion-word-language-modeling-benchmark/heldout-harem/harem.heldout-00044-of-00050
# writing from /media/discoD/repositorios/1-billion-word-language-modeling-benchmark/heldout-harem/harem.heldout-00045-of-00050
# writing from /media/discoD/repositorios/1-billion-word-language-modeling-benchmark/heldout-harem/harem.heldout-00046-of-00050
# writing from /media/discoD/repositorios/1-billion-word-language-modeling-benchmark/heldout-harem/harem.heldout-00047-of-00050
# writing from /media/discoD/repositorios/1-billion-word-language-modeling-benchmark/heldout-harem/harem.heldout-00048-of-00050
# writing from /media/discoD/repositorios/1-billion-word-language-modeling-benchmark/heldout-harem/harem.heldout-00049-of-00050
# 51 texts saved to test_harem_pt.csv
# writing from /media/discoD/repositorios/1-billion-word-language-modeling-benchmark/training-harem/harem-00001-of-00100
# writing from /media/discoD/repositorios/1-billion-word-language-modeling-benchmark/training-harem/harem-00002-of-00100
# writing from /media/discoD/repositorios/1-billion-word-language-modeling-benchmark/training-harem/harem-00003-of-00100
# writing from /media/discoD/repositorios/1-billion-word-language-modeling-benchmark/training-harem/harem-00004-of-00100
# writing from /media/discoD/repositorios/1-billion-word-language-modeling-benchmark/training-harem/harem-00005-of-00100
# writing from /media/discoD/repositorios/1-billion-word-language-modeling-benchmark/training-harem/harem-00006-of-00100
# writing from /media/discoD/repositorios/1-billion-word-language-modeling-benchmark/training-harem/harem-00007-of-00100
# writing from /media/discoD/repositorios/1-billion-word-language-modeling-benchmark/training-harem/harem-00008-of-00100
# writing from /media/discoD/repositorios/1-billion-word-language-modeling-benchmark/training-harem/harem-00009-of-00100
# writing from /media/discoD/repositorios/1-billion-word-language-modeling-benchmark/training-harem/harem-00010-of-00100
# writing from /media/discoD/repositorios/1-billion-word-language-modeling-benchmark/training-harem/harem-00011-of-00100
# writing from /media/discoD/repositorios/1-billion-word-language-modeling-benchmark/training-harem/harem-00012-of-00100
# writing from /media/discoD/repositorios/1-billion-word-language-modeling-benchmark/training-harem/harem-00013-of-00100
# writing from /media/discoD/repositorios/1-billion-word-language-modeling-benchmark/training-harem/harem-00014-of-00100
# writing from /media/discoD/repositorios/1-billion-word-language-modeling-benchmark/training-harem/harem-00016-of-00100
# writing from /media/discoD/repositorios/1-billion-word-language-modeling-benchmark/training-harem/harem-00017-of-00100
# writing from /media/discoD/repositorios/1-billion-word-language-modeling-benchmark/training-harem/harem-00018-of-00100
# writing from /media/discoD/repositorios/1-billion-word-language-modeling-benchmark/training-harem/harem-00019-of-00100
# writing from /media/discoD/repositorios/1-billion-word-language-modeling-benchmark/training-harem/harem-00020-of-00100
# writing from /media/discoD/repositorios/1-billion-word-language-modeling-benchmark/training-harem/harem-00021-of-00100
# writing from /media/discoD/repositorios/1-billion-word-language-modeling-benchmark/training-harem/harem-00022-of-00100
# writing from /media/discoD/repositorios/1-billion-word-language-modeling-benchmark/training-harem/harem-00023-of-00100
# writing from /media/discoD/repositorios/1-billion-word-language-modeling-benchmark/training-harem/harem-00024-of-00100
# writing from /media/discoD/repositorios/1-billion-word-language-modeling-benchmark/training-harem/harem-00025-of-00100
# writing from /media/discoD/repositorios/1-billion-word-language-modeling-benchmark/training-harem/harem-00026-of-00100
# writing from /media/discoD/repositorios/1-billion-word-language-modeling-benchmark/training-harem/harem-00027-of-00100
# writing from /media/discoD/repositorios/1-billion-word-language-modeling-benchmark/training-harem/harem-00028-of-00100
# writing from /media/discoD/repositorios/1-billion-word-language-modeling-benchmark/training-harem/harem-00029-of-00100
# writing from /media/discoD/repositorios/1-billion-word-language-modeling-benchmark/training-harem/harem-00030-of-00100
# writing from /media/discoD/repositorios/1-billion-word-language-modeling-benchmark/training-harem/harem-00032-of-00100
# writing from /media/discoD/repositorios/1-billion-word-language-modeling-benchmark/training-harem/harem-00033-of-00100
# writing from /media/discoD/repositorios/1-billion-word-language-modeling-benchmark/training-harem/harem-00034-of-00100
# writing from /media/discoD/repositorios/1-billion-word-language-modeling-benchmark/training-harem/harem-00035-of-00100
# writing from /media/discoD/repositorios/1-billion-word-language-modeling-benchmark/training-harem/harem-00036-of-00100
# writing from /media/discoD/repositorios/1-billion-word-language-modeling-benchmark/training-harem/harem-00037-of-00100
# writing from /media/discoD/repositorios/1-billion-word-language-modeling-benchmark/training-harem/harem-00038-of-00100
# writing from /media/discoD/repositorios/1-billion-word-language-modeling-benchmark/training-harem/harem-00039-of-00100
# writing from /media/discoD/repositorios/1-billion-word-language-modeling-benchmark/training-harem/harem-00040-of-00100
# writing from /media/discoD/repositorios/1-billion-word-language-modeling-benchmark/training-harem/harem-00041-of-00100
# writing from /media/discoD/repositorios/1-billion-word-language-modeling-benchmark/training-harem/harem-00042-of-00100
# writing from /media/discoD/repositorios/1-billion-word-language-modeling-benchmark/training-harem/harem-00043-of-00100
# writing from /media/discoD/repositorios/1-billion-word-language-modeling-benchmark/training-harem/harem-00044-of-00100
# writing from /media/discoD/repositorios/1-billion-word-language-modeling-benchmark/training-harem/harem-00045-of-00100
# writing from /media/discoD/repositorios/1-billion-word-language-modeling-benchmark/training-harem/harem-00046-of-00100
# writing from /media/discoD/repositorios/1-billion-word-language-modeling-benchmark/training-harem/harem-00048-of-00100
# writing from /media/discoD/repositorios/1-billion-word-language-modeling-benchmark/training-harem/harem-00049-of-00100
# writing from /media/discoD/repositorios/1-billion-word-language-modeling-benchmark/training-harem/harem-00050-of-00100
# writing from /media/discoD/repositorios/1-billion-word-language-modeling-benchmark/training-harem/harem-00051-of-00100
# writing from /media/discoD/repositorios/1-billion-word-language-modeling-benchmark/training-harem/harem-00052-of-00100
# writing from /media/discoD/repositorios/1-billion-word-language-modeling-benchmark/training-harem/harem-00053-of-00100
# writing from /media/discoD/repositorios/1-billion-word-language-modeling-benchmark/training-harem/harem-00054-of-00100
# writing from /media/discoD/repositorios/1-billion-word-language-modeling-benchmark/training-harem/harem-00055-of-00100
# writing from /media/discoD/repositorios/1-billion-word-language-modeling-benchmark/training-harem/harem-00056-of-00100
# writing from /media/discoD/repositorios/1-billion-word-language-modeling-benchmark/training-harem/harem-00057-of-00100
# writing from /media/discoD/repositorios/1-billion-word-language-modeling-benchmark/training-harem/harem-00058-of-00100
# writing from /media/discoD/repositorios/1-billion-word-language-modeling-benchmark/training-harem/harem-00059-of-00100
# writing from /media/discoD/repositorios/1-billion-word-language-modeling-benchmark/training-harem/harem-00060-of-00100
# writing from /media/discoD/repositorios/1-billion-word-language-modeling-benchmark/training-harem/harem-00061-of-00100
# writing from /media/discoD/repositorios/1-billion-word-language-modeling-benchmark/training-harem/harem-00062-of-00100
# writing from /media/discoD/repositorios/1-billion-word-language-modeling-benchmark/training-harem/harem-00015-of-00100
# writing from /media/discoD/repositorios/1-billion-word-language-modeling-benchmark/training-harem/harem-00031-of-00100
# writing from /media/discoD/repositorios/1-billion-word-language-modeling-benchmark/training-harem/harem-00047-of-00100
# writing from /media/discoD/repositorios/1-billion-word-language-modeling-benchmark/training-harem/harem-00063-of-00100
# writing from /media/discoD/repositorios/1-billion-word-language-modeling-benchmark/training-harem/harem-00079-of-00100
# writing from /media/discoD/repositorios/1-billion-word-language-modeling-benchmark/training-harem/harem-00064-of-00100
# writing from /media/discoD/repositorios/1-billion-word-language-modeling-benchmark/training-harem/harem-00065-of-00100
# writing from /media/discoD/repositorios/1-billion-word-language-modeling-benchmark/training-harem/harem-00066-of-00100
# writing from /media/discoD/repositorios/1-billion-word-language-modeling-benchmark/training-harem/harem-00067-of-00100
# writing from /media/discoD/repositorios/1-billion-word-language-modeling-benchmark/training-harem/harem-00068-of-00100
# writing from /media/discoD/repositorios/1-billion-word-language-modeling-benchmark/training-harem/harem-00069-of-00100
# writing from /media/discoD/repositorios/1-billion-word-language-modeling-benchmark/training-harem/harem-00070-of-00100
# writing from /media/discoD/repositorios/1-billion-word-language-modeling-benchmark/training-harem/harem-00071-of-00100
# writing from /media/discoD/repositorios/1-billion-word-language-modeling-benchmark/training-harem/harem-00072-of-00100
# writing from /media/discoD/repositorios/1-billion-word-language-modeling-benchmark/training-harem/harem-00073-of-00100
# writing from /media/discoD/repositorios/1-billion-word-language-modeling-benchmark/training-harem/harem-00074-of-00100
# writing from /media/discoD/repositorios/1-billion-word-language-modeling-benchmark/training-harem/harem-00075-of-00100
# writing from /media/discoD/repositorios/1-billion-word-language-modeling-benchmark/training-harem/harem-00076-of-00100
# writing from /media/discoD/repositorios/1-billion-word-language-modeling-benchmark/training-harem/harem-00077-of-00100
# writing from /media/discoD/repositorios/1-billion-word-language-modeling-benchmark/training-harem/harem-00078-of-00100
# writing from /media/discoD/repositorios/1-billion-word-language-modeling-benchmark/training-harem/harem-00080-of-00100
# writing from /media/discoD/repositorios/1-billion-word-language-modeling-benchmark/training-harem/harem-00081-of-00100
# writing from /media/discoD/repositorios/1-billion-word-language-modeling-benchmark/training-harem/harem-00082-of-00100
# writing from /media/discoD/repositorios/1-billion-word-language-modeling-benchmark/training-harem/harem-00083-of-00100
# writing from /media/discoD/repositorios/1-billion-word-language-modeling-benchmark/training-harem/harem-00084-of-00100
# writing from /media/discoD/repositorios/1-billion-word-language-modeling-benchmark/training-harem/harem-00085-of-00100
# writing from /media/discoD/repositorios/1-billion-word-language-modeling-benchmark/training-harem/harem-00086-of-00100
# writing from /media/discoD/repositorios/1-billion-word-language-modeling-benchmark/training-harem/harem-00087-of-00100
# writing from /media/discoD/repositorios/1-billion-word-language-modeling-benchmark/training-harem/harem-00088-of-00100
# writing from /media/discoD/repositorios/1-billion-word-language-modeling-benchmark/training-harem/harem-00089-of-00100
# writing from /media/discoD/repositorios/1-billion-word-language-modeling-benchmark/training-harem/harem-00090-of-00100
# writing from /media/discoD/repositorios/1-billion-word-language-modeling-benchmark/training-harem/harem-00091-of-00100
# writing from /media/discoD/repositorios/1-billion-word-language-modeling-benchmark/training-harem/harem-00092-of-00100
# writing from /media/discoD/repositorios/1-billion-word-language-modeling-benchmark/training-harem/harem-00093-of-00100
# writing from /media/discoD/repositorios/1-billion-word-language-modeling-benchmark/training-harem/harem-00094-of-00100
# writing from /media/discoD/repositorios/1-billion-word-language-modeling-benchmark/training-harem/harem-00095-of-00100
# writing from /media/discoD/repositorios/1-billion-word-language-modeling-benchmark/training-harem/harem-00096-of-00100
# writing from /media/discoD/repositorios/1-billion-word-language-modeling-benchmark/training-harem/harem-00097-of-00100
# writing from /media/discoD/repositorios/1-billion-word-language-modeling-benchmark/training-harem/harem-00098-of-00100
# writing from /media/discoD/repositorios/1-billion-word-language-modeling-benchmark/training-harem/harem-00099-of-00100
# writing from /media/discoD/repositorios/1-billion-word-language-modeling-benchmark/heldout-harem/harem.heldout-00013-of-00050
# writing from /media/discoD/repositorios/1-billion-word-language-modeling-benchmark/heldout-harem/harem.heldout-00027-of-00050
# writing from /media/discoD/repositorios/1-billion-word-language-modeling-benchmark/heldout-harem/harem-00000-of-00100
# writing from /media/discoD/repositorios/1-billion-word-language-modeling-benchmark/heldout-harem/harem.heldout-00000-of-00050
# writing from /media/discoD/repositorios/1-billion-word-language-modeling-benchmark/heldout-harem/harem.heldout-00001-of-00050
# writing from /media/discoD/repositorios/1-billion-word-language-modeling-benchmark/heldout-harem/harem.heldout-00002-of-00050
# writing from /media/discoD/repositorios/1-billion-word-language-modeling-benchmark/heldout-harem/harem.heldout-00003-of-00050
# writing from /media/discoD/repositorios/1-billion-word-language-modeling-benchmark/heldout-harem/harem.heldout-00004-of-00050
# writing from /media/discoD/repositorios/1-billion-word-language-modeling-benchmark/heldout-harem/harem.heldout-00005-of-00050
# writing from /media/discoD/repositorios/1-billion-word-language-modeling-benchmark/heldout-harem/harem.heldout-00006-of-00050
# writing from /media/discoD/repositorios/1-billion-word-language-modeling-benchmark/heldout-harem/harem.heldout-00007-of-00050
# writing from /media/discoD/repositorios/1-billion-word-language-modeling-benchmark/heldout-harem/harem.heldout-00008-of-00050
# writing from /media/discoD/repositorios/1-billion-word-language-modeling-benchmark/heldout-harem/harem.heldout-00009-of-00050
# writing from /media/discoD/repositorios/1-billion-word-language-modeling-benchmark/heldout-harem/harem.heldout-00010-of-00050
# writing from /media/discoD/repositorios/1-billion-word-language-modeling-benchmark/heldout-harem/harem.heldout-00011-of-00050
# writing from /media/discoD/repositorios/1-billion-word-language-modeling-benchmark/heldout-harem/harem.heldout-00012-of-00050
# writing from /media/discoD/repositorios/1-billion-word-language-modeling-benchmark/heldout-harem/harem.heldout-00014-of-00050
# writing from /media/discoD/repositorios/1-billion-word-language-modeling-benchmark/heldout-harem/harem.heldout-00015-of-00050
# writing from /media/discoD/repositorios/1-billion-word-language-modeling-benchmark/heldout-harem/harem.heldout-00016-of-00050
# writing from /media/discoD/repositorios/1-billion-word-language-modeling-benchmark/heldout-harem/harem.heldout-00017-of-00050
# writing from /media/discoD/repositorios/1-billion-word-language-modeling-benchmark/heldout-harem/harem.heldout-00018-of-00050
# writing from /media/discoD/repositorios/1-billion-word-language-modeling-benchmark/heldout-harem/harem.heldout-00019-of-00050
# writing from /media/discoD/repositorios/1-billion-word-language-modeling-benchmark/heldout-harem/harem.heldout-00020-of-00050
# writing from /media/discoD/repositorios/1-billion-word-language-modeling-benchmark/heldout-harem/harem.heldout-00021-of-00050
# writing from /media/discoD/repositorios/1-billion-word-language-modeling-benchmark/heldout-harem/harem.heldout-00022-of-00050
# writing from /media/discoD/repositorios/1-billion-word-language-modeling-benchmark/heldout-harem/harem.heldout-00023-of-00050
# writing from /media/discoD/repositorios/1-billion-word-language-modeling-benchmark/heldout-harem/harem.heldout-00024-of-00050
# writing from /media/discoD/repositorios/1-billion-word-language-modeling-benchmark/heldout-harem/harem.heldout-00025-of-00050
# writing from /media/discoD/repositorios/1-billion-word-language-modeling-benchmark/heldout-harem/harem.heldout-00026-of-00050
# writing from /media/discoD/repositorios/1-billion-word-language-modeling-benchmark/heldout-harem/harem.heldout-00028-of-00050
# writing from /media/discoD/repositorios/1-billion-word-language-modeling-benchmark/heldout-harem/harem.heldout-00029-of-00050
# writing from /media/discoD/repositorios/1-billion-word-language-modeling-benchmark/heldout-harem/harem.heldout-00030-of-00050
# writing from /media/discoD/repositorios/1-billion-word-language-modeling-benchmark/heldout-harem/harem.heldout-00031-of-00050
# writing from /media/discoD/repositorios/1-billion-word-language-modeling-benchmark/heldout-harem/harem.heldout-00032-of-00050
# writing from /media/discoD/repositorios/1-billion-word-language-modeling-benchmark/heldout-harem/harem.heldout-00033-of-00050
# writing from /media/discoD/repositorios/1-billion-word-language-modeling-benchmark/heldout-harem/harem.heldout-00034-of-00050
# writing from /media/discoD/repositorios/1-billion-word-language-modeling-benchmark/heldout-harem/harem.heldout-00035-of-00050
# writing from /media/discoD/repositorios/1-billion-word-language-modeling-benchmark/heldout-harem/harem.heldout-00036-of-00050
# writing from /media/discoD/repositorios/1-billion-word-language-modeling-benchmark/heldout-harem/harem.heldout-00037-of-00050
# writing from /media/discoD/repositorios/1-billion-word-language-modeling-benchmark/heldout-harem/harem.heldout-00038-of-00050
# writing from /media/discoD/repositorios/1-billion-word-language-modeling-benchmark/heldout-harem/harem.heldout-00039-of-00050
# writing from /media/discoD/repositorios/1-billion-word-language-modeling-benchmark/heldout-harem/harem.heldout-00040-of-00050
# writing from /media/discoD/repositorios/1-billion-word-language-modeling-benchmark/heldout-harem/harem.heldout-00041-of-00050
# writing from /media/discoD/repositorios/1-billion-word-language-modeling-benchmark/heldout-harem/harem.heldout-00042-of-00050
# writing from /media/discoD/repositorios/1-billion-word-language-modeling-benchmark/heldout-harem/harem.heldout-00043-of-00050
# writing from /media/discoD/repositorios/1-billion-word-language-modeling-benchmark/heldout-harem/harem.heldout-00044-of-00050
# writing from /media/discoD/repositorios/1-billion-word-language-modeling-benchmark/heldout-harem/harem.heldout-00045-of-00050
# writing from /media/discoD/repositorios/1-billion-word-language-modeling-benchmark/heldout-harem/harem.heldout-00046-of-00050
# writing from /media/discoD/repositorios/1-billion-word-language-modeling-benchmark/heldout-harem/harem.heldout-00047-of-00050
# writing from /media/discoD/repositorios/1-billion-word-language-modeling-benchmark/heldout-harem/harem.heldout-00048-of-00050
# writing from /media/discoD/repositorios/1-billion-word-language-modeling-benchmark/heldout-harem/harem.heldout-00049-of-00050
# 150 texts saved to full_harem_pt.csv

# %%
def get_tokens(filename):
    data = pd.read_csv(filename, header=None, escapechar='\\', chunksize=500000)
    for idx, df in enumerate(data):
        print(idx)
        yield VocabularyTokenizer().process_all(df[0].astype(str))

# %%
freq_full = Counter(p for o in chain.from_iterable(get_tokens('full_harem_pt.csv')) for p in o)
freq_full.most_common()
# Out:
# 0
# [(',', 39537),
#  ('"', 39255),
#  ('de', 24784),
#  ('.', 21202),
#  ('a', 18659),
#  ('e', 14020),
#  ('o', 13513),
#  ('que', 12737),
#  ('do', 8234),
#  ('da', 7947),
#  ('em', 6072),
#  ('para', 5626),
#  ('os', 4893),
#  ('um', 4565),
#  ('com', 4399),
#  ('uma', 4118),
#  ('no', 3561),
#  ('é', 3558),
#  ('não', 3472),
#  ('na', 3263),
#  ('-', 3053),
#  ('as', 2934),
#  ('dos', 2831),
#  ('se', 2781),
#  (':', 2745),
#  ('por', 2650),
#  (')', 2641),
#  ('(', 2571),
#  ('à', 2445),
#  ('O', 2381),
#  ('mais', 2361),
#  ('A', 2296),
#  ('como', 2017),
#  ('das', 1854),
#  ('?', 1803),
#  ('d', 1579),
#  ('«', 1520),
#  ('»', 1515),
#  ('foi', 1501),
#  ('/', 1411),
#  ('sua', 1250),
#  ('ou', 1221),
#  (';', 1193),
#  ('mas', 1164),
#  ('E', 1138),
#  ('ser', 1119),
#  ('era', 1104),
#  ('muito', 1073),
#  ('nos', 993),
#  ('eu', 986),
#  ('seu', 977),
#  ('pela', 944),
#  ('também', 934),
#  ('já', 931),
#  ('anos', 908),
#  ('sobre', 894),
#  ('pelo', 892),
#  ('!', 889),
#  ('tem', 879),
#  ('n', 873),
#  ('este', 870),
#  ('ele', 824),
#  ('...', 821),
#  ('esta', 763),
#  ('são', 758),
#  ('entre', 745),
#  ('ainda', 683),
#  ('s', 675),
#  ('está', 670),
#  ('até', 652),
#  ('isso', 646),
#  ('todos', 631),
#  ('porque', 627),
#  ('Os', 608),
#  ('quando', 595),
#  ('Em', 588),
#  ('tinha', 586),
#  ('Não', 562),
#  ('seus', 560),
#  ('bem', 559),
#  ('ter', 551),
#  ('onde', 549),
#  ('depois', 534),
#  ('fazer', 521),
#  ('mesmo', 520),
#  ('aqui', 515),
#  ('só', 513),
#  ('nas', 511),
#  ('É', 510),
#  ('grande', 509),
#  ('me', 503),
#  ("'", 493),
#  ('dia', 491),
#  ('Brasil', 491),
#  ('há', 489),
#  ('tempo', 480),
#  ('lá', 479),
#  ('eles', 475),
#  ('--', 472),
#  ('São', 472),
#  ('ela', 468),
#  ('ano', 467),
#  ('outros', 466),
#  ('pessoas', 463),
#  ('vez', 462),
#  ('sem', 459),
#  ('Mas', 459),
#  ('dois', 454),
#  ('essa', 453),
#  ('R', 443),
#  ('assim', 442),
#  ('esse', 430),
#  ('minha', 430),
#  ('vida', 422),
#  ('meu', 417),
#  ('casa', 411),
#  ('parte', 407),
#  ('sempre', 405),
#  ('No', 403),
#  ('hoje', 398),
#  ('P', 398),
#  ('gente', 397),
#  ('tudo', 394),
#  ('nós', 385),
#  ('pode', 383),
#  ('As', 382),
#  ('foram', 379),
#  ('trabalho', 369),
#  ('forma', 355),
#  ('programa', 350),
#  ('cada', 348),
#  ('Comissão', 347),
#  ('Paulo', 346),
#  ('Para', 346),
#  ('$', 341),
#  ('três', 338),
#  ('vai', 338),
#  ('Eu', 336),
#  ('suas', 329),
#  ('Por', 327),
#  ('primeiro', 321),
#  ('cidade', 319),
#  ('então', 318),
#  ('%', 317),
#  ('estão', 314),
#  ('maior', 311),
#  ('primeira', 308),
#  ('pouco', 305),
#  ('outro', 303),
#  ('num', 302),
#  ('lhe', 299),
#  ('todo', 299),
#  ('agora', 299),
#  ('nem', 296),
#  ('país', 293),
#  ('dizer', 292),
#  ('pelos', 291),
#  ('outras', 291),
#  ('senhor', 288),
#  ('coisa', 286),
#  ('Como', 285),
#  ('Presidente', 284),
#  ('mundo', 284),
#  ('numa', 283),
#  ('estava', 281),
#  ('nossa', 275),
#  ('desenvolvimento', 273),
#  ('Porto', 273),
#  ('Portugal', 270),
#  ('quem', 269),
#  ('desde', 268),
#  ('José', 268),
#  ('disse', 265),
#  ('menos', 264),
#  ('nome', 261),
#  ('mil', 259),
#  ('Na', 257),
#  ('Estado', 255),
#  ('contra', 254),
#  ('presidente', 249),
#  ('Universidade', 249),
#  ('seja', 249),
#  ('todas', 248),
#  ('novo', 248),
#  ('duas', 247),
#  ('apenas', 247),
#  ('será', 244),
#  ('Se', 243),
#  ('tão', 243),
#  ('melhor', 240),
#  ('toda', 239),
#  ('ver', 239),
#  ('nosso', 238),
#  ('qual', 238),
#  ('vezes', 237),
#  ('milhões', 237),
#  ('política', 237),
#  ('alguns', 236),
#  ('eram', 236),
#  ('2000', 236),
#  ('Conselho', 233),
#  ('segundo', 233),
#  ('países', 233),
#  ('ontem', 232),
#  ('empresa', 232),
#  ('têm', 232),
#  ('Com', 231),
#  ('pai', 228),
#  ('De', 227),
#  ('durante', 225),
#  ('quer', 224),
#  ('Rio', 222),
#  ('área', 221),
#  ('sido', 216),
#  ('nada', 216),
#  ('lugar', 214),
#  ('governo', 213),
#  ('Um', 213),
#  ('qualquer', 212),
#  ('dias', 211),
#  ('processo', 210),
#  ('antes', 209),
#  ('você', 209),
#  ('mãe', 209),
#  ('meio', 208),
#  ('aquele', 207),
#  ('número', 206),
#  ('coisas', 206),
#  ('sendo', 205),
#  ('Maria', 205),
#  ('através', 204),
#  ('grandes', 203),
#  ('sistema', 202),
#  ('senhora', 202),
#  ('cerca', 202),
#  ('lado', 202),
#  ('horas', 200),
#  ('empresas', 200),
#  ('isto', 199),
#  ('Foi', 199),
#  ('exemplo', 199),
#  ('nova', 199),
#  ('muitos', 198),
#  ('Quando', 197),
#  ('estes', 197),
#  ('tenho', 196),
#  ('aquela', 196),
#  ('|', 196),
#  ('tanto', 194),
#  ('Uma', 194),
#  ('dar', 193),
#  ('Nacional', 193),
#  ('relação', 190),
#  ('noite', 190),
#  ('algumas', 188),
#  ('aí', 187),
#  ('1', 187),
#  ('outra', 186),
#  ('Lisboa', 186),
#  ('Carlos', 186),
#  ('grupo', 185),
#  ('mercado', 185),
#  ('alguma', 183),
#  ('caso', 182),
#  ('ali', 182),
#  ('partir', 182),
#  ('Este', 182),
#  ('_', 181),
#  ('Parlamento', 180),
#  ('acordo', 179),
#  ('Depois', 178),
#  ('2', 176),
#  ('quatro', 176),
#  ('família', 175),
#  ('João', 175),
#  ('diz', 174),
#  ('Europa', 173),
#  ('Então', 172),
#  ('fim', 172),
#  ('importante', 172),
#  ('informação', 171),
#  ('ponto', 171),
#  ('ia', 170),
#  ('momento', 170),
#  ('DE', 170),
#  ('facto', 169),
#  ('quase', 169),
#  ('quais', 168),
#  ('água', 167),
#  ('nunca', 166),
#  ('proposta', 166),
#  ('nossos', 166),
#  ('tal', 166),
#  ('qualidade', 166),
#  ('região', 166),
#  ('estar', 165),
#  ('além', 163),
#  ('serviços', 163),
#  ('estas', 163),
#  ('história', 162),
#  ('faz', 162),
#  ('fez', 162),
#  ('Senhor', 161),
#  ('local', 160),
#  ('mesma', 160),
#  ('esses', 160),
#  ('programas', 158),
#  ('Esta', 158),
#  ('Governo', 158),
#  ('possível', 158),
#  ('problemas', 157),
#  ('pois', 156),
#  ('teve', 156),
#  ('nível', 156),
#  ('20', 156),
#  ('altura', 154),
#  ('passado', 154),
#  ('havia', 154),
#  ('questão', 154),
#  ('Associação', 153),
#  ('bom', 152),
#  ('fora', 150),
#  ('sentido', 150),
#  ('nan', 150),
#  ('futuro', 149),
#  ('R-', 149),
#  ('essas', 149),
#  ('Era', 149),
#  ('Internet', 148),
#  ('social', 148),
#  ('podem', 148),
#  ('formação', 147),
#  ('apoio', 147),
#  ('pelas', 147),
#  ('Braga', 146),
#  ('conta', 146),
#  ('ir', 146),
#  ('forte', 146),
#  ('10', 145),
#  ('dentro', 145),
#  ('modo', 145),
#  ('quanto', 145),
#  ('vamos', 144),
#  ('livro', 144),
#  ('http', 144),
#  ('poder', 144),
#  ('3', 143),
#  ('deputado', 143),
#  ('início', 143),
#  ('muitas', 143),
#  ('final', 143),
#  ('homem', 142),
#  ('terra', 141),
#  ('saber', 141),
#  ('@', 141),
#  ('tendo', 141),
#  ('vários', 141),
#  ('União', 140),
#  ('condições', 139),
#  ('30', 139),
#  ('fui', 138),
#  ('né', 138),
#  ('Câmara', 137),
#  ('após', 137),
#  ('temos', 137),
#  ('escola', 137),
#  ('Segundo', 136),
#  ('deve', 136),
#  ('meus', 136),
#  ('relatório', 135),
#  ('situação', 135),
#  ('produtos', 135),
#  ('vista', 134),
#  ('cinco', 134),
#  ('logo', 134),
#  ('trabalhar', 134),
#  ('Ele', 133),
#  ('boa', 133),
#  ('tarde', 133),
#  ('meses', 132),
#  ('época', 132),
#  ('dinheiro', 132),
#  ('jovens', 131),
#  ('+', 130),
#  ('25', 130),
#  ('alunos', 129),
#  ('base', 129),
#  ('volta', 129),
#  ('Janeiro', 128),
#  ('Centro', 128),
#  ('público', 128),
#  ('nacional', 128),
#  ('sabe', 128),
#  ('Instituto', 128),
#  ('Já', 128),
#  ('começou', 128),
#  ('tipo', 128),
#  ('mim', 127),
#  ('enquanto', 127),
#  ('homens', 127),
#  ('novos', 126),
#  ('período', 126),
#  ('mulher', 125),
#  ('Há', 125),
#  ('resultados', 125),
#  ('15', 125),
#  ('novas', 124),
#  ('longo', 124),
#  ('uns', 123),
#  ('seria', 123),
#  ('12', 123),
#  ('&', 122),
#  ('papel', 122),
#  ('4', 121),
#  ('cultura', 121),
#  ('pessoa', 121),
#  ('espaço', 120),
#  ('muita', 120),
#  ('pontos', 119),
#  ('2001', 119),
#  ('direitos', 119),
#  ('2002', 119),
#  ('aqueles', 119),
#  ('problema', 119),
#  ('Ao', 118),
#  ('sei', 118),
#  ('trabalhos', 118),
#  ('professor', 117),
#  ('Estados', 117),
#  ('falar', 117),
#  ('Rua', 117),
#  ('fazia', 117),
#  ('embora', 117),
#  ('mês', 117),
#  ('pais', 117),
#  ('D.', 116),
#  ('recursos', 116),
#  ('11', 116),
#  ('crianças', 116),
#  ('queria', 116),
#  ('terá', 115),
#  ('projecto', 115),
#  ('veio', 114),
#  ('Que', 114),
#  ('junto', 114),
#  ('conjunto', 114),
#  ('valor', 114),
#  ('Deus', 113),
#  ('portugueses', 113),
#  ('respeito', 113),
#  ('vem', 112),
#  ('semana', 112),
#  ('produção', 111),
#  ('economia', 111),
#  ('5', 111),
#  ('maneira', 111),
#  ('geral', 110),
#  ('poderá', 110),
#  ('Educação', 110),
#  ('diferentes', 110),
#  ('contos', 110),
#  ('próprio', 110),
#  ('investigação', 110),
#  ('português', 109),
#  ('maioria', 109),
#  ('etc', 109),
#  ('Escola', 109),
#  ('sociedade', 109),
#  ('entanto', 109),
#  ('fase', 109),
#  ('António', 109),
#  ('áreas', 109),
#  ('segurança', 108),
#  ('transporte', 108),
#  ('feito', 108),
#  ('curso', 108),
#  ('principal', 108),
#  ('vão', 107),
#  ('comunicação', 107),
#  ('verdade', 107),
#  ('termos', 107),
#  ('criação', 107),
#  ('informações', 107),
#  ('elas', 107),
#  ('causa', 107),
#  ('18', 106),
#  ('segunda', 106),
#  ('dados', 106),
#  ('ordem', 106),
#  ('cento', 105),
#  ('site', 105),
#  ('mão', 104),
#  ('cá', 104),
#  ('te', 104),
#  ('último', 104),
#  ('fosse', 104),
#  ('ambiente', 103),
#  ('Assim', 103),
#  ('gestão', 103),
#  ('serão', 102),
#  ('saúde', 102),
#  ('portuguesa', 102),
#  ('bastante', 102),
#  ('Agora', 102),
#  ('sob', 102),
#  ('ficou', 101),
#  ('principais', 100),
#  ('perto', 100),
#  ('Silva', 100),
#  ('linha', 99),
#  ('ensino', 99),
#  ('importância', 99),
#  ('Senhora', 99),
#  ('deu', 99),
#  ('rio', 99),
#  ('Informação', 99),
#  ('objectivo', 99),
#  ('gostaria', 98),
#  ('várias', 98),
#  ('estudantes', 98),
#  ('frente', 98),
#  ('50', 98),
#  ('razão', 98),
#  ('Sul', 97),
#  ('rua', 97),
#  ('membros', 97),
#  ('rede', 97),
#  ('aquilo', 96),
#  ('obra', 96),
#  ('·', 96),
#  ('série', 96),
#  ('música', 96),
#  ('filhos', 96),
#  ('ninguém', 96),
#  ('manhã', 96),
#  ('EUA', 95),
#  ('documento', 95),
#  ('estamos', 95),
#  ('sector', 95),
#  ('Europeia', 95),
#  ('Além', 95),
#  ('7', 95),
#  ('olhos', 95),
#  ('projectos', 95),
#  ('total', 94),
#  ('decisão', 94),
#  ('grupos', 94),
#  ('16', 94),
#  ('algum', 94),
#  ('Pedro', 94),
#  ('acesso', 93),
#  ('[', 93),
#  (']', 93),
#  ('existe', 93),
#  ('*', 93),
#  ('últimos', 93),
#  ('parece', 93),
#  ('estavam', 92),
#  ('passou', 92),
#  ('amigos', 92),
#  ('pesquisa', 92),
#  ('1999', 92),
#  ('tinham', 92),
#  ('ficar', 91),
#  ('Social', 91),
#  ('Banco', 91),
#  ('reunião', 91),
#  ('sobretudo', 91),
#  ('caminho', 91),
#  ('capital', 91),
#  ('construção', 90),
#  ('cultural', 90),
#  ('mal', 90),
#  ('serviço', 90),
#  ('presente', 90),
#  ('13', 90),
#  ('devem', 89),
#  ('estudo', 89),
#  ('direito', 89),
#  ('povo', 89),
#  ('Também', 89),
#  ('mulheres', 89),
#  ('presença', 89),
#  ('seis', 88),
#  ('II', 88),
#  ('posição', 88),
#  ('for', 88),
#  ('dá', 88),
#  ('necessidade', 88),
#  ('chegou', 88),
#  ('educação', 88),
#  ('professores', 87),
#  ('internacional', 87),
#  ('própria', 87),
#  ('interesse', 87),
#  ('necessário', 87),
#  ('população', 87),
#  ('seguinte', 87),
#  ('crescimento', 87),
#  ('debate', 86),
#  ('pública', 86),
#  ('hora', 86),
#  ('tenha', 86),
#  ('sou', 86),
#  ('energia', 86),
#  ('equipa', 86),
#  ('estou', 86),
#  ('século', 86),
#  ('passar', 86),
#  ('nomeadamente', 85),
#  ('fica', 85),
#  ('objectivos', 85),
#  ('realidade', 85),
#  ('plano', 85),
#  ('medidas', 85),
#  ('estado', 85),
#  ('ideia', 85),
#  ('Grupo', 85),
#  ('ministro', 85),
#  ('conhecimento', 84),
#  ('página', 84),
#  ('Ministério', 84),
#  ('matéria', 84),
#  ('portanto', 84),
#  ('livros', 84),
#  ('Programa', 84),
#  ('passa', 84),
#  ('si', 84),
#  ('jogo', 84),
#  ('alterações', 83),
#  ('feita', 83),
#  ('certo', 83),
#  ('dez', 83),
#  ('Faculdade', 83),
#  ('Europeu', 83),
#  ('14', 83),
#  ('Ciência', 83),
#  ('pé', 83),
#  ('cursos', 83),
#  ('Tem', 83),
#  ('Santos', 83),
#  ('participação', 82),
#  ('Cultura', 82),
#  ('pra', 82),
#  ('pequena', 82),
#  ('guerra', 82),
#  ('força', 82),
#  ('opinião', 82),
#  ('iniciativa', 82),
#  ('resultado', 81),
#  ('experiência', 81),
#  ('alteração', 81),
#  ('clientes', 80),
#  ('Mais', 80),
#  ('Municipal', 80),
#  ('atenção', 80),
#  ('primeiros', 80),
#  ('existem', 80),
#  ('difícil', 80),
#  ('centro', 80),
#  ('projeto', 80),
#  ('língua', 79),
#  ('Luís', 79),
#  ('favor', 79),
#  ('amigo', 79),
#  ('palavras', 79),
#  ('actividade', 79),
#  ('possibilidade', 79),
#  ('pessoal', 79),
#  ('responsável', 79),
#  ('US', 79),
#  ('falta', 79),
#  ('assunto', 79),
#  ('Fernando', 79),
#  ('diversas', 79),
#  ('Santo', 78),
#  ('especial', 78),
#  ('colegas', 78),
#  ('Entre', 78),
#  ('talvez', 78),
#  ('Abril', 78),
#  ('Unidos', 77),
#  ('40', 77),
#  ('conhecer', 77),
#  ('medida', 77),
#  ('preços', 77),
#  ('instituições', 77),
#  ('pequeno', 77),
#  ('diferente', 77),
#  ('chegar', 77),
#  ('capacidade', 77),
#  ('Isso', 77),
#  ('receber', 77),
#  ('sejam', 77),
#  ('actividades', 77),
#  ('Nós', 77),
#  ('levar', 77),
#  ('corpo', 77),
#  ('Todos', 76),
#  ('Central', 76),
#  ('coração', 76),
#  ('título', 76),
#  ('deverá', 76),
#  ('efeito', 76),
#  ('Nos', 76),
#  ('cima', 76),
#  ('Hoje', 75),
#  ('Desenvolvimento', 75),
#  ('nº', 75),
#  ('vou', 75),
#  ('valores', 75),
#  ('preciso', 75),
#  ('âmbito', 75),
#  ('aumento', 75),
#  ('próximo', 75),
#  ('e-mail', 75),
#  ('Só', 74),
#  ('vontade', 74),
#  ('sociais', 74),
#  ('60', 74),
#  ('idade', 74),
#  ('via', 74),
#  ('Alemanha', 74),
#  ('21', 74),
#  ('serem', 74),
#  ('nacionais', 74),
#  ('6', 74),
#  ('diversos', 74),
#  ('irmãos', 74),
#  ('Grande', 74),
#  ('importantes', 73),
#  ('maiores', 73),
#  ('melhores', 73),
#  ('profissional', 73),
#  ('questões', 73),
#  ('arte', 73),
#  ('Folha', 73),
#  ('24', 73),
#  ('evento', 73),
#  ('interior', 73),
#  ('equipe', 73),
#  ('Neste', 73),
#  ('nenhum', 73),
#  ('mundial', 73),
#  ('existência', 73),
#  ('redução', 72),
#  ('origem', 72),
#  ('última', 72),
#  ('Espanha', 72),
#  ('I', 72),
#  ('comum', 72),
#  ('lista', 72),
#  ('acção', 72),
#  ('movimento', 72),
#  ('tecnologia', 71),
#  ('podemos', 71),
#  ('Qual', 71),
#  ('S.', 71),
#  ('obras', 71),
#  ('8', 71),
#  ('tentar', 71),
#  ('zona', 71),
#  ('longe', 71),
#  ('nossas', 71),
#  ('velho', 71),
#  ('fundo', 71),
#  ('lei', 71),
#  ('17', 71),
#  ('9', 71),
#  ('moedas', 71),
#  ('nasceu', 70),
#  ('político', 70),
#  ('criança', 70),
#  ('oito', 70),
#  ('Santa', 70),
#  ('simples', 70),
#  ('domínio', 70),
#  ('Isto', 70),
#  ('morte', 70),
#  ('Porque', 70),
#  ('devido', 70),
#  ('execução', 69),
#  ('propostas', 69),
#  ('República', 69),
#  ('dificuldades', 69),
#  ('sim', 69),
#  ('Ela', 69),
#  ('acabou', 69),
#  ('defesa', 69),
#  ('resposta', 69),
#  ('tema', 69),
#  ('actual', 69),
#  ('prazo', 69),
#  ('loja', 69),
#  ('europeia', 69),
#  ('acções', 69),
#  ('texto', 69),
#  ('tive', 69),
#  ('sete', 68),
#  ('gosto', 68),
#  ('podia', 68),
#  ('lhes', 68),
#  ('relações', 68),
#  ('Março', 68),
#  ('19', 68),
#  ('cidadãos', 68),
#  ('Dr.', 68),
#  ('participantes', 68),
#  ('única', 68),
#  ('princípio', 68),
#  ('promover', 68),
#  ('permite', 67),
#  ('data', 67),
#  ('andar', 67),
#  ('oportunidade', 67),
#  ('mar', 67),
#  ('acho', 67),
#  ('manter', 67),
#  ('Nova', 67),
#  ('humanos', 67),
#  ('administração', 67),
#  ('eleições', 67),
#  ('Maio', 67),
#  ('Minho', 67),
#  ('ajuda', 67),
#  ('estrutura', 67),
#  ('deixou', 67),
#  ('futebol', 67),
#  ('vir', 67),
#  ('Saúde', 66),
#  ('tomar', 66),
#  ('organização', 66),
#  ('poderia', 66),
#  ('22', 66),
#  ('umas', 66),
#  ('desenvolver', 66),
#  ('liberdade', 66),
#  ('dado', 66),
#  ('Eles', 66),
#  ('políticas', 66),
#  ('apesar', 66),
#  ('universidade', 66),
#  ('Manuel', 66),
#  ('tempos', 66),
#  ('Quanto', 66),
#  ('Mundial', 65),
#  ('casos', 65),
#  ('dizia', 65),
#  ('análise', 65),
#  ('campanha', 65),
#  ('pequenos', 65),
#  ('encontrar', 65),
#  ('Henrique', 65),
#  ('Geral', 65),
#  ('central', 64),
#  ('meios', 64),
#  ('possa', 64),
#  ('natural', 64),
#  ('tratamento', 64),
#  ('Ciências', 64),
#  ('filho', 64),
#  ('campo', 64),
#  ('uso', 64),
#  ('estudar', 63),
#  ('Você', 63),
#  ('euros', 63),
#  ('políticos', 63),
#  ('profissionais', 63),
#  ('continua', 63),
#  ('encontro', 63),
#  ('Vila', 63),
#  ('natureza', 63),
#  ('ouro', 63),
#  ('2003', 63),
#  ('Internacional', 63),
#  ('dava', 63),
#  ('prática', 63),
#  ('100', 63),
#  ('vinha', 63),
#  ('cuja', 63),
#  ('cabeça', 63),
#  ('comissão', 62),
#  ('Até', 62),
#  ('Da', 62),
#  ('temas', 62),
#  ('criar', 62),
#  ('Filosofia', 62),
#  ('resolução', 62),
#  ('paz', 62),
#  ('porta', 62),
#  ('igualmente', 62),
#  ('deixar', 62),
#  ('Casa', 62),
#  ('livre', 62),
#  ('Clube', 62),
#  ('pedido', 62),
#  ('DO', 62),
#  ('afirmou', 62),
#  ('tu', 62),
#  ('espera', 61),
#  ('França', 61),
#  ('internacionais', 61),
#  ('Dias', 61),
#  ('seguir', 61),
#  ('passo', 61),
#  ('exposição', 61),
#  ('Região', 61),
#  ('relativamente', 61),
#  ('imprensa', 61),
#  ('desejo', 61),
#  ('afirma', 61),
#  ('procura', 61),
#  ('europeus', 61),
#  ('Esse', 61),
#  ('sucesso', 61),
#  ('Quem', 61),
#  ('conseguir', 60),
#  ('elementos', 60),
#  ('fazem', 60),
#  ('particular', 60),
#  ('Sistema', 60),
#  ('custos', 60),
#  ('apresentação', 60),
#  ('SP', 60),
#  ('Partido', 60),
#  ('pretende', 60),
#  ('mãos', 60),
#  ('Itália', 60),
#  ('computador', 60),
#  ('produto', 60),
#  ('comercial', 60),
#  ('minutos', 60),
#  ('artigo', 60),
#  ('construir', 60),
#  ('resto', 59),
#  ('transportes', 59),
#  ('próxima', 59),
#  ('houve', 59),
#  ('comunidade', 59),
#  ('filha', 59),
#  ('1997', 59),
#  ('alta', 59),
#  ('Costa', 59),
#  ('função', 59),
#  ('colégio', 59),
#  ('bons', 59),
#  ('partes', 59),
#  ('Museu', 59),
#  ('real', 59),
#  ('Congresso', 58),
#  ('atividades', 58),
#  ('marido', 58),
#  ('metros', 58),
#  ('enorme', 58),
#  ('Norte', 58),
#  ('festa', 58),
#  ('modelo', 58),
#  ('entrada', 58),
#  ('sala', 58),
#  ('Francisco', 58),
#  ('preço', 58),
#  ('extremamente', 58),
#  ('cedo', 58),
#  ('francês', 58),
#  ('públicos', 58),
#  ('viagem', 58),
#  ('funções', 57),
#  ('menor', 57),
#  ('partido', 57),
#  ('comércio', 57),
#  ('alto', 57),
#  ('imagem', 57),
#  ('único', 57),
#  ('Ainda', 57),
#  ('Apesar', 57),
#  ('DA', 57),
#  ('fizeram', 57),
#  ('seguintes', 57),
#  ('luta', 57),
#  ('brasileira', 57),
#  ('sistemas', 57),
#  ('barco', 57),
#  ('Departamento', 57),
#  ('entrar', 57),
#  ('sede', 56),
#  ('cooperação', 56),
#  ('objetivo', 56),
#  ('necessidades', 56),
#  ('contar', 56),
#  ('Portuguesa', 56),
#  ('espécie', 56),
#  ('aspecto', 56),
#  ('distância', 56),
#  ('fazendo', 56),
#  ('fácil', 56),
#  ('candidato', 56),
#  ('técnica', 56),
#  ('claro', 56),
#  ('palavra', 56),
#  ('locais', 56),
#  ...]

# %%
palavras = [palavra for palavra, contagem in freq_full.most_common()]
palavras
# Out:
# [',',
#  '"',
#  'de',
#  '.',
#  'a',
#  'e',
#  'o',
#  'que',
#  'do',
#  'da',
#  'em',
#  'para',
#  'os',
#  'um',
#  'com',
#  'uma',
#  'no',
#  'é',
#  'não',
#  'na',
#  '-',
#  'as',
#  'dos',
#  'se',
#  ':',
#  'por',
#  ')',
#  '(',
#  'à',
#  'O',
#  'mais',
#  'A',
#  'como',
#  'das',
#  '?',
#  'd',
#  '«',
#  '»',
#  'foi',
#  '/',
#  'sua',
#  'ou',
#  ';',
#  'mas',
#  'E',
#  'ser',
#  'era',
#  'muito',
#  'nos',
#  'eu',
#  'seu',
#  'pela',
#  'também',
#  'já',
#  'anos',
#  'sobre',
#  'pelo',
#  '!',
#  'tem',
#  'n',
#  'este',
#  'ele',
#  '...',
#  'esta',
#  'são',
#  'entre',
#  'ainda',
#  's',
#  'está',
#  'até',
#  'isso',
#  'todos',
#  'porque',
#  'Os',
#  'quando',
#  'Em',
#  'tinha',
#  'Não',
#  'seus',
#  'bem',
#  'ter',
#  'onde',
#  'depois',
#  'fazer',
#  'mesmo',
#  'aqui',
#  'só',
#  'nas',
#  'É',
#  'grande',
#  'me',
#  "'",
#  'dia',
#  'Brasil',
#  'há',
#  'tempo',
#  'lá',
#  'eles',
#  '--',
#  'São',
#  'ela',
#  'ano',
#  'outros',
#  'pessoas',
#  'vez',
#  'sem',
#  'Mas',
#  'dois',
#  'essa',
#  'R',
#  'assim',
#  'esse',
#  'minha',
#  'vida',
#  'meu',
#  'casa',
#  'parte',
#  'sempre',
#  'No',
#  'hoje',
#  'P',
#  'gente',
#  'tudo',
#  'nós',
#  'pode',
#  'As',
#  'foram',
#  'trabalho',
#  'forma',
#  'programa',
#  'cada',
#  'Comissão',
#  'Paulo',
#  'Para',
#  '$',
#  'três',
#  'vai',
#  'Eu',
#  'suas',
#  'Por',
#  'primeiro',
#  'cidade',
#  'então',
#  '%',
#  'estão',
#  'maior',
#  'primeira',
#  'pouco',
#  'outro',
#  'num',
#  'lhe',
#  'todo',
#  'agora',
#  'nem',
#  'país',
#  'dizer',
#  'pelos',
#  'outras',
#  'senhor',
#  'coisa',
#  'Como',
#  'Presidente',
#  'mundo',
#  'numa',
#  'estava',
#  'nossa',
#  'desenvolvimento',
#  'Porto',
#  'Portugal',
#  'quem',
#  'desde',
#  'José',
#  'disse',
#  'menos',
#  'nome',
#  'mil',
#  'Na',
#  'Estado',
#  'contra',
#  'presidente',
#  'Universidade',
#  'seja',
#  'todas',
#  'novo',
#  'duas',
#  'apenas',
#  'será',
#  'Se',
#  'tão',
#  'melhor',
#  'toda',
#  'ver',
#  'nosso',
#  'qual',
#  'vezes',
#  'milhões',
#  'política',
#  'alguns',
#  'eram',
#  '2000',
#  'Conselho',
#  'segundo',
#  'países',
#  'ontem',
#  'empresa',
#  'têm',
#  'Com',
#  'pai',
#  'De',
#  'durante',
#  'quer',
#  'Rio',
#  'área',
#  'sido',
#  'nada',
#  'lugar',
#  'governo',
#  'Um',
#  'qualquer',
#  'dias',
#  'processo',
#  'antes',
#  'você',
#  'mãe',
#  'meio',
#  'aquele',
#  'número',
#  'coisas',
#  'sendo',
#  'Maria',
#  'através',
#  'grandes',
#  'sistema',
#  'senhora',
#  'cerca',
#  'lado',
#  'horas',
#  'empresas',
#  'isto',
#  'Foi',
#  'exemplo',
#  'nova',
#  'muitos',
#  'Quando',
#  'estes',
#  'tenho',
#  'aquela',
#  '|',
#  'tanto',
#  'Uma',
#  'dar',
#  'Nacional',
#  'relação',
#  'noite',
#  'algumas',
#  'aí',
#  '1',
#  'outra',
#  'Lisboa',
#  'Carlos',
#  'grupo',
#  'mercado',
#  'alguma',
#  'caso',
#  'ali',
#  'partir',
#  'Este',
#  '_',
#  'Parlamento',
#  'acordo',
#  'Depois',
#  '2',
#  'quatro',
#  'família',
#  'João',
#  'diz',
#  'Europa',
#  'Então',
#  'fim',
#  'importante',
#  'informação',
#  'ponto',
#  'ia',
#  'momento',
#  'DE',
#  'facto',
#  'quase',
#  'quais',
#  'água',
#  'nunca',
#  'proposta',
#  'nossos',
#  'tal',
#  'qualidade',
#  'região',
#  'estar',
#  'além',
#  'serviços',
#  'estas',
#  'história',
#  'faz',
#  'fez',
#  'Senhor',
#  'local',
#  'mesma',
#  'esses',
#  'programas',
#  'Esta',
#  'Governo',
#  'possível',
#  'problemas',
#  'pois',
#  'teve',
#  'nível',
#  '20',
#  'altura',
#  'passado',
#  'havia',
#  'questão',
#  'Associação',
#  'bom',
#  'fora',
#  'sentido',
#  'nan',
#  'futuro',
#  'R-',
#  'essas',
#  'Era',
#  'Internet',
#  'social',
#  'podem',
#  'formação',
#  'apoio',
#  'pelas',
#  'Braga',
#  'conta',
#  'ir',
#  'forte',
#  '10',
#  'dentro',
#  'modo',
#  'quanto',
#  'vamos',
#  'livro',
#  'http',
#  'poder',
#  '3',
#  'deputado',
#  'início',
#  'muitas',
#  'final',
#  'homem',
#  'terra',
#  'saber',
#  '@',
#  'tendo',
#  'vários',
#  'União',
#  'condições',
#  '30',
#  'fui',
#  'né',
#  'Câmara',
#  'após',
#  'temos',
#  'escola',
#  'Segundo',
#  'deve',
#  'meus',
#  'relatório',
#  'situação',
#  'produtos',
#  'vista',
#  'cinco',
#  'logo',
#  'trabalhar',
#  'Ele',
#  'boa',
#  'tarde',
#  'meses',
#  'época',
#  'dinheiro',
#  'jovens',
#  '+',
#  '25',
#  'alunos',
#  'base',
#  'volta',
#  'Janeiro',
#  'Centro',
#  'público',
#  'nacional',
#  'sabe',
#  'Instituto',
#  'Já',
#  'começou',
#  'tipo',
#  'mim',
#  'enquanto',
#  'homens',
#  'novos',
#  'período',
#  'mulher',
#  'Há',
#  'resultados',
#  '15',
#  'novas',
#  'longo',
#  'uns',
#  'seria',
#  '12',
#  '&',
#  'papel',
#  '4',
#  'cultura',
#  'pessoa',
#  'espaço',
#  'muita',
#  'pontos',
#  '2001',
#  'direitos',
#  '2002',
#  'aqueles',
#  'problema',
#  'Ao',
#  'sei',
#  'trabalhos',
#  'professor',
#  'Estados',
#  'falar',
#  'Rua',
#  'fazia',
#  'embora',
#  'mês',
#  'pais',
#  'D.',
#  'recursos',
#  '11',
#  'crianças',
#  'queria',
#  'terá',
#  'projecto',
#  'veio',
#  'Que',
#  'junto',
#  'conjunto',
#  'valor',
#  'Deus',
#  'portugueses',
#  'respeito',
#  'vem',
#  'semana',
#  'produção',
#  'economia',
#  '5',
#  'maneira',
#  'geral',
#  'poderá',
#  'Educação',
#  'diferentes',
#  'contos',
#  'próprio',
#  'investigação',
#  'português',
#  'maioria',
#  'etc',
#  'Escola',
#  'sociedade',
#  'entanto',
#  'fase',
#  'António',
#  'áreas',
#  'segurança',
#  'transporte',
#  'feito',
#  'curso',
#  'principal',
#  'vão',
#  'comunicação',
#  'verdade',
#  'termos',
#  'criação',
#  'informações',
#  'elas',
#  'causa',
#  '18',
#  'segunda',
#  'dados',
#  'ordem',
#  'cento',
#  'site',
#  'mão',
#  'cá',
#  'te',
#  'último',
#  'fosse',
#  'ambiente',
#  'Assim',
#  'gestão',
#  'serão',
#  'saúde',
#  'portuguesa',
#  'bastante',
#  'Agora',
#  'sob',
#  'ficou',
#  'principais',
#  'perto',
#  'Silva',
#  'linha',
#  'ensino',
#  'importância',
#  'Senhora',
#  'deu',
#  'rio',
#  'Informação',
#  'objectivo',
#  'gostaria',
#  'várias',
#  'estudantes',
#  'frente',
#  '50',
#  'razão',
#  'Sul',
#  'rua',
#  'membros',
#  'rede',
#  'aquilo',
#  'obra',
#  '·',
#  'série',
#  'música',
#  'filhos',
#  'ninguém',
#  'manhã',
#  'EUA',
#  'documento',
#  'estamos',
#  'sector',
#  'Europeia',
#  'Além',
#  '7',
#  'olhos',
#  'projectos',
#  'total',
#  'decisão',
#  'grupos',
#  '16',
#  'algum',
#  'Pedro',
#  'acesso',
#  '[',
#  ']',
#  'existe',
#  '*',
#  'últimos',
#  'parece',
#  'estavam',
#  'passou',
#  'amigos',
#  'pesquisa',
#  '1999',
#  'tinham',
#  'ficar',
#  'Social',
#  'Banco',
#  'reunião',
#  'sobretudo',
#  'caminho',
#  'capital',
#  'construção',
#  'cultural',
#  'mal',
#  'serviço',
#  'presente',
#  '13',
#  'devem',
#  'estudo',
#  'direito',
#  'povo',
#  'Também',
#  'mulheres',
#  'presença',
#  'seis',
#  'II',
#  'posição',
#  'for',
#  'dá',
#  'necessidade',
#  'chegou',
#  'educação',
#  'professores',
#  'internacional',
#  'própria',
#  'interesse',
#  'necessário',
#  'população',
#  'seguinte',
#  'crescimento',
#  'debate',
#  'pública',
#  'hora',
#  'tenha',
#  'sou',
#  'energia',
#  'equipa',
#  'estou',
#  'século',
#  'passar',
#  'nomeadamente',
#  'fica',
#  'objectivos',
#  'realidade',
#  'plano',
#  'medidas',
#  'estado',
#  'ideia',
#  'Grupo',
#  'ministro',
#  'conhecimento',
#  'página',
#  'Ministério',
#  'matéria',
#  'portanto',
#  'livros',
#  'Programa',
#  'passa',
#  'si',
#  'jogo',
#  'alterações',
#  'feita',
#  'certo',
#  'dez',
#  'Faculdade',
#  'Europeu',
#  '14',
#  'Ciência',
#  'pé',
#  'cursos',
#  'Tem',
#  'Santos',
#  'participação',
#  'Cultura',
#  'pra',
#  'pequena',
#  'guerra',
#  'força',
#  'opinião',
#  'iniciativa',
#  'resultado',
#  'experiência',
#  'alteração',
#  'clientes',
#  'Mais',
#  'Municipal',
#  'atenção',
#  'primeiros',
#  'existem',
#  'difícil',
#  'centro',
#  'projeto',
#  'língua',
#  'Luís',
#  'favor',
#  'amigo',
#  'palavras',
#  'actividade',
#  'possibilidade',
#  'pessoal',
#  'responsável',
#  'US',
#  'falta',
#  'assunto',
#  'Fernando',
#  'diversas',
#  'Santo',
#  'especial',
#  'colegas',
#  'Entre',
#  'talvez',
#  'Abril',
#  'Unidos',
#  '40',
#  'conhecer',
#  'medida',
#  'preços',
#  'instituições',
#  'pequeno',
#  'diferente',
#  'chegar',
#  'capacidade',
#  'Isso',
#  'receber',
#  'sejam',
#  'actividades',
#  'Nós',
#  'levar',
#  'corpo',
#  'Todos',
#  'Central',
#  'coração',
#  'título',
#  'deverá',
#  'efeito',
#  'Nos',
#  'cima',
#  'Hoje',
#  'Desenvolvimento',
#  'nº',
#  'vou',
#  'valores',
#  'preciso',
#  'âmbito',
#  'aumento',
#  'próximo',
#  'e-mail',
#  'Só',
#  'vontade',
#  'sociais',
#  '60',
#  'idade',
#  'via',
#  'Alemanha',
#  '21',
#  'serem',
#  'nacionais',
#  '6',
#  'diversos',
#  'irmãos',
#  'Grande',
#  'importantes',
#  'maiores',
#  'melhores',
#  'profissional',
#  'questões',
#  'arte',
#  'Folha',
#  '24',
#  'evento',
#  'interior',
#  'equipe',
#  'Neste',
#  'nenhum',
#  'mundial',
#  'existência',
#  'redução',
#  'origem',
#  'última',
#  'Espanha',
#  'I',
#  'comum',
#  'lista',
#  'acção',
#  'movimento',
#  'tecnologia',
#  'podemos',
#  'Qual',
#  'S.',
#  'obras',
#  '8',
#  'tentar',
#  'zona',
#  'longe',
#  'nossas',
#  'velho',
#  'fundo',
#  'lei',
#  '17',
#  '9',
#  'moedas',
#  'nasceu',
#  'político',
#  'criança',
#  'oito',
#  'Santa',
#  'simples',
#  'domínio',
#  'Isto',
#  'morte',
#  'Porque',
#  'devido',
#  'execução',
#  'propostas',
#  'República',
#  'dificuldades',
#  'sim',
#  'Ela',
#  'acabou',
#  'defesa',
#  'resposta',
#  'tema',
#  'actual',
#  'prazo',
#  'loja',
#  'europeia',
#  'acções',
#  'texto',
#  'tive',
#  'sete',
#  'gosto',
#  'podia',
#  'lhes',
#  'relações',
#  'Março',
#  '19',
#  'cidadãos',
#  'Dr.',
#  'participantes',
#  'única',
#  'princípio',
#  'promover',
#  'permite',
#  'data',
#  'andar',
#  'oportunidade',
#  'mar',
#  'acho',
#  'manter',
#  'Nova',
#  'humanos',
#  'administração',
#  'eleições',
#  'Maio',
#  'Minho',
#  'ajuda',
#  'estrutura',
#  'deixou',
#  'futebol',
#  'vir',
#  'Saúde',
#  'tomar',
#  'organização',
#  'poderia',
#  '22',
#  'umas',
#  'desenvolver',
#  'liberdade',
#  'dado',
#  'Eles',
#  'políticas',
#  'apesar',
#  'universidade',
#  'Manuel',
#  'tempos',
#  'Quanto',
#  'Mundial',
#  'casos',
#  'dizia',
#  'análise',
#  'campanha',
#  'pequenos',
#  'encontrar',
#  'Henrique',
#  'Geral',
#  'central',
#  'meios',
#  'possa',
#  'natural',
#  'tratamento',
#  'Ciências',
#  'filho',
#  'campo',
#  'uso',
#  'estudar',
#  'Você',
#  'euros',
#  'políticos',
#  'profissionais',
#  'continua',
#  'encontro',
#  'Vila',
#  'natureza',
#  'ouro',
#  '2003',
#  'Internacional',
#  'dava',
#  'prática',
#  '100',
#  'vinha',
#  'cuja',
#  'cabeça',
#  'comissão',
#  'Até',
#  'Da',
#  'temas',
#  'criar',
#  'Filosofia',
#  'resolução',
#  'paz',
#  'porta',
#  'igualmente',
#  'deixar',
#  'Casa',
#  'livre',
#  'Clube',
#  'pedido',
#  'DO',
#  'afirmou',
#  'tu',
#  'espera',
#  'França',
#  'internacionais',
#  'Dias',
#  'seguir',
#  'passo',
#  'exposição',
#  'Região',
#  'relativamente',
#  'imprensa',
#  'desejo',
#  'afirma',
#  'procura',
#  'europeus',
#  'Esse',
#  'sucesso',
#  'Quem',
#  'conseguir',
#  'elementos',
#  'fazem',
#  'particular',
#  'Sistema',
#  'custos',
#  'apresentação',
#  'SP',
#  'Partido',
#  'pretende',
#  'mãos',
#  'Itália',
#  'computador',
#  'produto',
#  'comercial',
#  'minutos',
#  'artigo',
#  'construir',
#  'resto',
#  'transportes',
#  'próxima',
#  'houve',
#  'comunidade',
#  'filha',
#  '1997',
#  'alta',
#  'Costa',
#  'função',
#  'colégio',
#  'bons',
#  'partes',
#  'Museu',
#  'real',
#  'Congresso',
#  'atividades',
#  'marido',
#  'metros',
#  'enorme',
#  'Norte',
#  'festa',
#  'modelo',
#  'entrada',
#  'sala',
#  'Francisco',
#  'preço',
#  'extremamente',
#  'cedo',
#  'francês',
#  'públicos',
#  'viagem',
#  'funções',
#  'menor',
#  'partido',
#  'comércio',
#  'alto',
#  'imagem',
#  'único',
#  'Ainda',
#  'Apesar',
#  'DA',
#  'fizeram',
#  'seguintes',
#  'luta',
#  'brasileira',
#  'sistemas',
#  'barco',
#  'Departamento',
#  'entrar',
#  'sede',
#  'cooperação',
#  'objetivo',
#  'necessidades',
#  'contar',
#  'Portuguesa',
#  'espécie',
#  'aspecto',
#  'distância',
#  'fazendo',
#  'fácil',
#  'candidato',
#  'técnica',
#  'claro',
#  'palavra',
#  'locais',
#  ...]

# %%
len(palavras)
# Out:
# 54645

# %%
palavras.insert(0, '<UNK>')
palavras.insert(0, '<S>')
palavras.insert(0, '</S>')
palavras
# Out:
# ['</S>',
#  '<S>',
#  '<UNK>',
#  ',',
#  '"',
#  'de',
#  '.',
#  'a',
#  'e',
#  'o',
#  'que',
#  'do',
#  'da',
#  'em',
#  'para',
#  'os',
#  'um',
#  'com',
#  'uma',
#  'no',
#  'é',
#  'não',
#  'na',
#  '-',
#  'as',
#  'dos',
#  'se',
#  ':',
#  'por',
#  ')',
#  '(',
#  'à',
#  'O',
#  'mais',
#  'A',
#  'como',
#  'das',
#  '?',
#  'd',
#  '«',
#  '»',
#  'foi',
#  '/',
#  'sua',
#  'ou',
#  ';',
#  'mas',
#  'E',
#  'ser',
#  'era',
#  'muito',
#  'nos',
#  'eu',
#  'seu',
#  'pela',
#  'também',
#  'já',
#  'anos',
#  'sobre',
#  'pelo',
#  '!',
#  'tem',
#  'n',
#  'este',
#  'ele',
#  '...',
#  'esta',
#  'são',
#  'entre',
#  'ainda',
#  's',
#  'está',
#  'até',
#  'isso',
#  'todos',
#  'porque',
#  'Os',
#  'quando',
#  'Em',
#  'tinha',
#  'Não',
#  'seus',
#  'bem',
#  'ter',
#  'onde',
#  'depois',
#  'fazer',
#  'mesmo',
#  'aqui',
#  'só',
#  'nas',
#  'É',
#  'grande',
#  'me',
#  "'",
#  'dia',
#  'Brasil',
#  'há',
#  'tempo',
#  'lá',
#  'eles',
#  '--',
#  'São',
#  'ela',
#  'ano',
#  'outros',
#  'pessoas',
#  'vez',
#  'sem',
#  'Mas',
#  'dois',
#  'essa',
#  'R',
#  'assim',
#  'esse',
#  'minha',
#  'vida',
#  'meu',
#  'casa',
#  'parte',
#  'sempre',
#  'No',
#  'hoje',
#  'P',
#  'gente',
#  'tudo',
#  'nós',
#  'pode',
#  'As',
#  'foram',
#  'trabalho',
#  'forma',
#  'programa',
#  'cada',
#  'Comissão',
#  'Paulo',
#  'Para',
#  '$',
#  'três',
#  'vai',
#  'Eu',
#  'suas',
#  'Por',
#  'primeiro',
#  'cidade',
#  'então',
#  '%',
#  'estão',
#  'maior',
#  'primeira',
#  'pouco',
#  'outro',
#  'num',
#  'lhe',
#  'todo',
#  'agora',
#  'nem',
#  'país',
#  'dizer',
#  'pelos',
#  'outras',
#  'senhor',
#  'coisa',
#  'Como',
#  'Presidente',
#  'mundo',
#  'numa',
#  'estava',
#  'nossa',
#  'desenvolvimento',
#  'Porto',
#  'Portugal',
#  'quem',
#  'desde',
#  'José',
#  'disse',
#  'menos',
#  'nome',
#  'mil',
#  'Na',
#  'Estado',
#  'contra',
#  'presidente',
#  'Universidade',
#  'seja',
#  'todas',
#  'novo',
#  'duas',
#  'apenas',
#  'será',
#  'Se',
#  'tão',
#  'melhor',
#  'toda',
#  'ver',
#  'nosso',
#  'qual',
#  'vezes',
#  'milhões',
#  'política',
#  'alguns',
#  'eram',
#  '2000',
#  'Conselho',
#  'segundo',
#  'países',
#  'ontem',
#  'empresa',
#  'têm',
#  'Com',
#  'pai',
#  'De',
#  'durante',
#  'quer',
#  'Rio',
#  'área',
#  'sido',
#  'nada',
#  'lugar',
#  'governo',
#  'Um',
#  'qualquer',
#  'dias',
#  'processo',
#  'antes',
#  'você',
#  'mãe',
#  'meio',
#  'aquele',
#  'número',
#  'coisas',
#  'sendo',
#  'Maria',
#  'através',
#  'grandes',
#  'sistema',
#  'senhora',
#  'cerca',
#  'lado',
#  'horas',
#  'empresas',
#  'isto',
#  'Foi',
#  'exemplo',
#  'nova',
#  'muitos',
#  'Quando',
#  'estes',
#  'tenho',
#  'aquela',
#  '|',
#  'tanto',
#  'Uma',
#  'dar',
#  'Nacional',
#  'relação',
#  'noite',
#  'algumas',
#  'aí',
#  '1',
#  'outra',
#  'Lisboa',
#  'Carlos',
#  'grupo',
#  'mercado',
#  'alguma',
#  'caso',
#  'ali',
#  'partir',
#  'Este',
#  '_',
#  'Parlamento',
#  'acordo',
#  'Depois',
#  '2',
#  'quatro',
#  'família',
#  'João',
#  'diz',
#  'Europa',
#  'Então',
#  'fim',
#  'importante',
#  'informação',
#  'ponto',
#  'ia',
#  'momento',
#  'DE',
#  'facto',
#  'quase',
#  'quais',
#  'água',
#  'nunca',
#  'proposta',
#  'nossos',
#  'tal',
#  'qualidade',
#  'região',
#  'estar',
#  'além',
#  'serviços',
#  'estas',
#  'história',
#  'faz',
#  'fez',
#  'Senhor',
#  'local',
#  'mesma',
#  'esses',
#  'programas',
#  'Esta',
#  'Governo',
#  'possível',
#  'problemas',
#  'pois',
#  'teve',
#  'nível',
#  '20',
#  'altura',
#  'passado',
#  'havia',
#  'questão',
#  'Associação',
#  'bom',
#  'fora',
#  'sentido',
#  'nan',
#  'futuro',
#  'R-',
#  'essas',
#  'Era',
#  'Internet',
#  'social',
#  'podem',
#  'formação',
#  'apoio',
#  'pelas',
#  'Braga',
#  'conta',
#  'ir',
#  'forte',
#  '10',
#  'dentro',
#  'modo',
#  'quanto',
#  'vamos',
#  'livro',
#  'http',
#  'poder',
#  '3',
#  'deputado',
#  'início',
#  'muitas',
#  'final',
#  'homem',
#  'terra',
#  'saber',
#  '@',
#  'tendo',
#  'vários',
#  'União',
#  'condições',
#  '30',
#  'fui',
#  'né',
#  'Câmara',
#  'após',
#  'temos',
#  'escola',
#  'Segundo',
#  'deve',
#  'meus',
#  'relatório',
#  'situação',
#  'produtos',
#  'vista',
#  'cinco',
#  'logo',
#  'trabalhar',
#  'Ele',
#  'boa',
#  'tarde',
#  'meses',
#  'época',
#  'dinheiro',
#  'jovens',
#  '+',
#  '25',
#  'alunos',
#  'base',
#  'volta',
#  'Janeiro',
#  'Centro',
#  'público',
#  'nacional',
#  'sabe',
#  'Instituto',
#  'Já',
#  'começou',
#  'tipo',
#  'mim',
#  'enquanto',
#  'homens',
#  'novos',
#  'período',
#  'mulher',
#  'Há',
#  'resultados',
#  '15',
#  'novas',
#  'longo',
#  'uns',
#  'seria',
#  '12',
#  '&',
#  'papel',
#  '4',
#  'cultura',
#  'pessoa',
#  'espaço',
#  'muita',
#  'pontos',
#  '2001',
#  'direitos',
#  '2002',
#  'aqueles',
#  'problema',
#  'Ao',
#  'sei',
#  'trabalhos',
#  'professor',
#  'Estados',
#  'falar',
#  'Rua',
#  'fazia',
#  'embora',
#  'mês',
#  'pais',
#  'D.',
#  'recursos',
#  '11',
#  'crianças',
#  'queria',
#  'terá',
#  'projecto',
#  'veio',
#  'Que',
#  'junto',
#  'conjunto',
#  'valor',
#  'Deus',
#  'portugueses',
#  'respeito',
#  'vem',
#  'semana',
#  'produção',
#  'economia',
#  '5',
#  'maneira',
#  'geral',
#  'poderá',
#  'Educação',
#  'diferentes',
#  'contos',
#  'próprio',
#  'investigação',
#  'português',
#  'maioria',
#  'etc',
#  'Escola',
#  'sociedade',
#  'entanto',
#  'fase',
#  'António',
#  'áreas',
#  'segurança',
#  'transporte',
#  'feito',
#  'curso',
#  'principal',
#  'vão',
#  'comunicação',
#  'verdade',
#  'termos',
#  'criação',
#  'informações',
#  'elas',
#  'causa',
#  '18',
#  'segunda',
#  'dados',
#  'ordem',
#  'cento',
#  'site',
#  'mão',
#  'cá',
#  'te',
#  'último',
#  'fosse',
#  'ambiente',
#  'Assim',
#  'gestão',
#  'serão',
#  'saúde',
#  'portuguesa',
#  'bastante',
#  'Agora',
#  'sob',
#  'ficou',
#  'principais',
#  'perto',
#  'Silva',
#  'linha',
#  'ensino',
#  'importância',
#  'Senhora',
#  'deu',
#  'rio',
#  'Informação',
#  'objectivo',
#  'gostaria',
#  'várias',
#  'estudantes',
#  'frente',
#  '50',
#  'razão',
#  'Sul',
#  'rua',
#  'membros',
#  'rede',
#  'aquilo',
#  'obra',
#  '·',
#  'série',
#  'música',
#  'filhos',
#  'ninguém',
#  'manhã',
#  'EUA',
#  'documento',
#  'estamos',
#  'sector',
#  'Europeia',
#  'Além',
#  '7',
#  'olhos',
#  'projectos',
#  'total',
#  'decisão',
#  'grupos',
#  '16',
#  'algum',
#  'Pedro',
#  'acesso',
#  '[',
#  ']',
#  'existe',
#  '*',
#  'últimos',
#  'parece',
#  'estavam',
#  'passou',
#  'amigos',
#  'pesquisa',
#  '1999',
#  'tinham',
#  'ficar',
#  'Social',
#  'Banco',
#  'reunião',
#  'sobretudo',
#  'caminho',
#  'capital',
#  'construção',
#  'cultural',
#  'mal',
#  'serviço',
#  'presente',
#  '13',
#  'devem',
#  'estudo',
#  'direito',
#  'povo',
#  'Também',
#  'mulheres',
#  'presença',
#  'seis',
#  'II',
#  'posição',
#  'for',
#  'dá',
#  'necessidade',
#  'chegou',
#  'educação',
#  'professores',
#  'internacional',
#  'própria',
#  'interesse',
#  'necessário',
#  'população',
#  'seguinte',
#  'crescimento',
#  'debate',
#  'pública',
#  'hora',
#  'tenha',
#  'sou',
#  'energia',
#  'equipa',
#  'estou',
#  'século',
#  'passar',
#  'nomeadamente',
#  'fica',
#  'objectivos',
#  'realidade',
#  'plano',
#  'medidas',
#  'estado',
#  'ideia',
#  'Grupo',
#  'ministro',
#  'conhecimento',
#  'página',
#  'Ministério',
#  'matéria',
#  'portanto',
#  'livros',
#  'Programa',
#  'passa',
#  'si',
#  'jogo',
#  'alterações',
#  'feita',
#  'certo',
#  'dez',
#  'Faculdade',
#  'Europeu',
#  '14',
#  'Ciência',
#  'pé',
#  'cursos',
#  'Tem',
#  'Santos',
#  'participação',
#  'Cultura',
#  'pra',
#  'pequena',
#  'guerra',
#  'força',
#  'opinião',
#  'iniciativa',
#  'resultado',
#  'experiência',
#  'alteração',
#  'clientes',
#  'Mais',
#  'Municipal',
#  'atenção',
#  'primeiros',
#  'existem',
#  'difícil',
#  'centro',
#  'projeto',
#  'língua',
#  'Luís',
#  'favor',
#  'amigo',
#  'palavras',
#  'actividade',
#  'possibilidade',
#  'pessoal',
#  'responsável',
#  'US',
#  'falta',
#  'assunto',
#  'Fernando',
#  'diversas',
#  'Santo',
#  'especial',
#  'colegas',
#  'Entre',
#  'talvez',
#  'Abril',
#  'Unidos',
#  '40',
#  'conhecer',
#  'medida',
#  'preços',
#  'instituições',
#  'pequeno',
#  'diferente',
#  'chegar',
#  'capacidade',
#  'Isso',
#  'receber',
#  'sejam',
#  'actividades',
#  'Nós',
#  'levar',
#  'corpo',
#  'Todos',
#  'Central',
#  'coração',
#  'título',
#  'deverá',
#  'efeito',
#  'Nos',
#  'cima',
#  'Hoje',
#  'Desenvolvimento',
#  'nº',
#  'vou',
#  'valores',
#  'preciso',
#  'âmbito',
#  'aumento',
#  'próximo',
#  'e-mail',
#  'Só',
#  'vontade',
#  'sociais',
#  '60',
#  'idade',
#  'via',
#  'Alemanha',
#  '21',
#  'serem',
#  'nacionais',
#  '6',
#  'diversos',
#  'irmãos',
#  'Grande',
#  'importantes',
#  'maiores',
#  'melhores',
#  'profissional',
#  'questões',
#  'arte',
#  'Folha',
#  '24',
#  'evento',
#  'interior',
#  'equipe',
#  'Neste',
#  'nenhum',
#  'mundial',
#  'existência',
#  'redução',
#  'origem',
#  'última',
#  'Espanha',
#  'I',
#  'comum',
#  'lista',
#  'acção',
#  'movimento',
#  'tecnologia',
#  'podemos',
#  'Qual',
#  'S.',
#  'obras',
#  '8',
#  'tentar',
#  'zona',
#  'longe',
#  'nossas',
#  'velho',
#  'fundo',
#  'lei',
#  '17',
#  '9',
#  'moedas',
#  'nasceu',
#  'político',
#  'criança',
#  'oito',
#  'Santa',
#  'simples',
#  'domínio',
#  'Isto',
#  'morte',
#  'Porque',
#  'devido',
#  'execução',
#  'propostas',
#  'República',
#  'dificuldades',
#  'sim',
#  'Ela',
#  'acabou',
#  'defesa',
#  'resposta',
#  'tema',
#  'actual',
#  'prazo',
#  'loja',
#  'europeia',
#  'acções',
#  'texto',
#  'tive',
#  'sete',
#  'gosto',
#  'podia',
#  'lhes',
#  'relações',
#  'Março',
#  '19',
#  'cidadãos',
#  'Dr.',
#  'participantes',
#  'única',
#  'princípio',
#  'promover',
#  'permite',
#  'data',
#  'andar',
#  'oportunidade',
#  'mar',
#  'acho',
#  'manter',
#  'Nova',
#  'humanos',
#  'administração',
#  'eleições',
#  'Maio',
#  'Minho',
#  'ajuda',
#  'estrutura',
#  'deixou',
#  'futebol',
#  'vir',
#  'Saúde',
#  'tomar',
#  'organização',
#  'poderia',
#  '22',
#  'umas',
#  'desenvolver',
#  'liberdade',
#  'dado',
#  'Eles',
#  'políticas',
#  'apesar',
#  'universidade',
#  'Manuel',
#  'tempos',
#  'Quanto',
#  'Mundial',
#  'casos',
#  'dizia',
#  'análise',
#  'campanha',
#  'pequenos',
#  'encontrar',
#  'Henrique',
#  'Geral',
#  'central',
#  'meios',
#  'possa',
#  'natural',
#  'tratamento',
#  'Ciências',
#  'filho',
#  'campo',
#  'uso',
#  'estudar',
#  'Você',
#  'euros',
#  'políticos',
#  'profissionais',
#  'continua',
#  'encontro',
#  'Vila',
#  'natureza',
#  'ouro',
#  '2003',
#  'Internacional',
#  'dava',
#  'prática',
#  '100',
#  'vinha',
#  'cuja',
#  'cabeça',
#  'comissão',
#  'Até',
#  'Da',
#  'temas',
#  'criar',
#  'Filosofia',
#  'resolução',
#  'paz',
#  'porta',
#  'igualmente',
#  'deixar',
#  'Casa',
#  'livre',
#  'Clube',
#  'pedido',
#  'DO',
#  'afirmou',
#  'tu',
#  'espera',
#  'França',
#  'internacionais',
#  'Dias',
#  'seguir',
#  'passo',
#  'exposição',
#  'Região',
#  'relativamente',
#  'imprensa',
#  'desejo',
#  'afirma',
#  'procura',
#  'europeus',
#  'Esse',
#  'sucesso',
#  'Quem',
#  'conseguir',
#  'elementos',
#  'fazem',
#  'particular',
#  'Sistema',
#  'custos',
#  'apresentação',
#  'SP',
#  'Partido',
#  'pretende',
#  'mãos',
#  'Itália',
#  'computador',
#  'produto',
#  'comercial',
#  'minutos',
#  'artigo',
#  'construir',
#  'resto',
#  'transportes',
#  'próxima',
#  'houve',
#  'comunidade',
#  'filha',
#  '1997',
#  'alta',
#  'Costa',
#  'função',
#  'colégio',
#  'bons',
#  'partes',
#  'Museu',
#  'real',
#  'Congresso',
#  'atividades',
#  'marido',
#  'metros',
#  'enorme',
#  'Norte',
#  'festa',
#  'modelo',
#  'entrada',
#  'sala',
#  'Francisco',
#  'preço',
#  'extremamente',
#  'cedo',
#  'francês',
#  'públicos',
#  'viagem',
#  'funções',
#  'menor',
#  'partido',
#  'comércio',
#  'alto',
#  'imagem',
#  'único',
#  'Ainda',
#  'Apesar',
#  'DA',
#  'fizeram',
#  'seguintes',
#  'luta',
#  'brasileira',
#  'sistemas',
#  'barco',
#  'Departamento',
#  'entrar',
#  'sede',
#  'cooperação',
#  'objetivo',
#  'necessidades',
#  'contar',
#  'Portuguesa',
#  'espécie',
#  'aspecto',
#  'distância',
#  'fazendo',
#  'fácil',
#  'candidato',
#  'técnica',
#  ...]

# %%
sum(freq_full.values())
# Out:
# 642977

# %%
def write_list(array, filename):
    with open(filename, 'w') as file:
        for item in array:
            file.write(item + '\n')
    file.close()

# %%
write_list(array=palavras, filename='vocabulario_harem.txt')

# %%
# !tail -n 10 vocabulario_harem.txt
# Out:
# Belenenses
# osTorneios
# Partiram
# Dorado
# senta-se
# levá-las
# magras
# recordar-lhe
# Lafaiete
# 1370

# %%
singletons = [palavra for palavra, contagem in freq_full.most_common() if contagem == 1]
print(len(singletons))
singletons
# Out:
# 29086
# ['intervenham',
#  'ciber-mundo',
#  'éextremamente',
#  'suportando',
#  'Agencias',
#  'consultam',
#  'acessores',
#  'presunção',
#  'anteparo',
#  'tacto',
#  'olfato',
#  'Orgulhosos',
#  'Valli',
#  'Artplan',
#  'cumprir-se',
#  'CSP',
#  'apetência',
#  '4.º',
#  'tabacaria',
#  'esgotar',
#  'toto',
#  'dispendido',
#  'Dou-me',
#  'suspendia',
#  'CLIENTE',
#  'Aponta-se',
#  'nomeia-se',
#  'açucareira',
#  'silvícola',
#  'concentrara',
#  'Hás-de',
#  'maispróximo',
#  'desburocratização',
#  'Markaz',
#  'Al-Dawat',
#  'wahabita',
#  'FERMIONS',
#  'latina',
#  'tabernas',
#  'Negativo',
#  '21º',
#  'distribuíram',
#  'X-15',
#  'procedamos',
#  'dividirei',
#  'louvar-vos-ei',
#  'repreender-vos-ei',
#  'cosidas',
#  'formarem',
#  'Piñero',
#  'Pratt',
#  'Vegetariana',
#  'Ulla',
#  'Sandbæk',
#  'tolos',
#  'Jürgen',
#  'Israelita',
#  '105º',
#  'Imagina-se',
#  'proveniência',
#  'Beiras',
#  'RESUMO',
#  'master-franqueado',
#  'rosbife',
#  'batatinhas',
#  'protótipo',
#  'porcento',
#  'voltaremos',
#  'incorporados',
#  'Surpreende-o',
#  'descaramento',
#  'obgetivos',
#  'aparencia',
#  'Joaquín',
#  'Encontrará',
#  'estaríamos',
#  'enlutadas',
#  'trevas',
#  'vitrina',
#  'barrocos',
#  'debruados',
#  'Glorioso',
#  'Pança',
#  'Guerras',
#  'Alecrim',
#  'Manjerona',
#  'habilitação',
#  'pré-hospitalar',
#  'primeiros-socorros',
#  'entusiasmei-me',
#  'Quental',
#  'pluridisciplnar',
#  'substituirmos',
#  'falece',
#  'entenderem-nos',
#  'has',
#  'been',
#  'approved',
#  'ANSI',
#  'available',
#  'despropósito',
#  'Eliany',
#  'dize-me',
#  'Soclnfo',
#  'Provo',
#  'Sanger',
#  'decifrou',
#  'medidas-padrão',
#  'insinuante',
#  'rego',
#  'transpusemo-lo',
#  'Pratico',
#  'aeróbica',
#  'entenda-se',
#  'residisse',
#  'comportou',
#  'Iria',
#  '11.233',
#  'conexoes',
#  'Viste',
#  'imundície',
#  'moleques',
#  'eucaristia',
#  'Intervém',
#  'encarrega',
#  'freqüências',
#  'Filhó',
#  'Portugália',
#  'reforçaram',
#  '26ºC',
#  'Météo',
#  'Apart',
#  'Castelos',
#  'rue',
#  'Maistre',
#  '75018',
#  'PARIS',
#  'Jean-Luc',
#  'Binet',
#  'terrass',
#  'FranceNet.fr',
#  'Analisei',
#  'taxativo',
#  'beltrano',
#  'sicrano',
#  'remetia',
#  'micro-créditos',
#  'falsificadas',
#  'Tributário',
#  'Previdenciária',
#  'Parecem',
#  'cardeal-arcebispo',
#  'Júpiter',
#  'àimprensa',
#  '--Medo',
#  'repetidas',
#  'Vento',
#  'Levou',
#  'olhado',
#  'requeria',
#  'orgulhamo-nos',
#  'Citroen',
#  'Lusitâna',
#  'Efacec',
#  'Corticeira',
#  'kla',
#  'emailserver.com.br',
#  'depravado',
#  'corava',
#  'Everts',
#  'multicampeão',
#  'ice-tea',
#  'Saulo',
#  'emprestar',
#  'enforcar',
#  'Free-Lance',
#  'extremo-poste',
#  '2,02',
#  'Kip',
#  '3,41',
#  'banhados',
#  'descongestionar',
#  'sobrecarregadas',
#  'pronúncia',
#  'portátil',
#  'voltagem',
#  'condutora',
#  'CPG',
#  'www.prossiga.cnpq.br',
#  'escaques',
#  'palmeirinhas',
#  'ornamentais',
#  'alegaram',
#  'conduzirão',
#  'triplicação',
#  'bombam',
#  'perpetrado',
#  'Condeixa-a-Nova',
#  'Montemor-o-Novo',
#  'Montemor-o-Velho',
#  'Nelas',
#  'Azeméis',
#  'Penela',
#  'Seia',
#  'requerer',
#  'Bula',
#  'Apostólica',
#  'Ecce',
#  'Tamanha',
#  'capitaneado',
#  'palmeirense',
#  'capões',
#  'ondulado',
#  'íngremes',
#  'lajedos',
#  'afloramento',
#  'escarpas',
#  'areníticas',
#  'MATRIZES',
#  'esforce',
#  'repletos',
#  'Propus-lhe',
#  'restaurar-se',
#  'fiz-lhe',
#  'pedi-lhe',
#  'admiti-o',
#  'escutei-o',
#  'urbanidade',
#  'surpreendia',
#  'corredios',
#  'acolhedor',
#  'populismo',
#  'exógeno',
#  'apetências',
#  'lusíada',
#  'deslumbramento',
#  'angolanas',
#  'encomiástica',
#  'referencialidade',
#  'onomástica',
#  '8.566',
#  'moeda-papel',
#  'régia',
#  'excediam',
#  'arrecadada',
#  'prestável',
#  'jantava',
#  'barulhento',
#  'acostou',
#  'enseada',
#  'Aniram',
#  'TRAZIDAS',
#  'ÂMBITO',
#  'EMPRESARIAL',
#  'Mando',
#  'reconheçamos',
#  'inflectiu',
#  'preconiza',
#  'Diamante',
#  'manchetes',
#  'convidamos',
#  '.Pratico',
#  'Visando',
#  'procedeu-se',
#  'engarrafamento',
#  'aquabou',
#  'prometo',
#  'cabimento',
#  'www.fenet.com.br',
#  'FENET',
#  'menospreze',
#  'Considerada',
#  'Peters',
#  'decorativas',
#  'decorar',
#  'remodelar',
#  'brilhar',
#  'lustre',
#  'Laurent',
#  'Acácio',
#  'Salero',
#  'visiense',
#  'macrocefalia',
#  'jazzman',
#  'Gausden',
#  'fraquejando',
#  'estegossauro',
#  'empreendedorismo',
#  'PMEs',
#  'www.nsdl.cornell.edu',
#  'Travessura',
#  'divertiu',
#  'Dossiers',
#  'Umacervejinha',
#  'juntávamos',
#  'asoutras',
#  'franguito',
#  'assávamos',
#  'eera',
#  'ficávamos',
#  'abrigossubterrâneos',
#  'genteficava',
#  'Porra',
#  'Aparecer',
#  'todosna',
#  'passaremos',
#  'prevalecer',
#  'identificacao',
#  '213174711',
#  '213528574',
#  'nojo',
#  'lembrei',
#  'Exemplificando',
#  'aconselharam',
#  'indisciplinas',
#  'norteou-se',
#  'Anais',
#  'micro-políticas',
#  'apartamentos',
#  'Hood',
#  'Electric',
#  'Radford',
#  'ZURIQUE',
#  'Camel',
#  'Fechei',
#  'inovou',
#  'caçasse',
#  'instrutivo',
#  'Trifásica',
#  'minuscularias',
#  'LÍNGUA',
#  'Oded',
#  'Grajew',
#  'grampeadas',
#  'escalada',
#  'engolida',
#  'calculam',
#  'doador',
#  '310,00',
#  'colhe',
#  'maltratar',
#  'enevoavam',
#  'Suaidem',
#  'Caloi',
#  'Menescal',
#  'arames',
#  'gibraltinas',
#  'folder',
#  'referenciais',
#  'norteiam',
#  'cumpri',
#  'governe',
#  'Osservatore',
#  'qualificou',
#  'mamas',
#  'Acrobáticos',
#  'Fratelli',
#  'homenageadas',
#  'biópsia',
#  'delgado',
#  'habitável',
#  'Giro',
#  'mantivéssemos',
#  'Cozia',
#  'espatifada',
#  'biscates',
#  '34.291',
#  'Frontal',
#  'administrados',
#  'FSESP',
#  'FNS',
#  'municipalidade',
#  'desvinculação',
#  'Analisando',
#  'isentos',
#  'recostado',
#  'sorrindo',
#  'mudeipara',
#  'Tanoeiro',
#  '864-5888',
#  'msoma4',
#  'Zairo',
#  'Cheibub',
#  'àvilania',
#  'àinfâmia',
#  'contrapoder',
#  'Parcelado',
#  '24X',
#  'capivaras',
#  'capturadas',
#  'aprisionadas',
#  'abatidas',
#  'povoada',
#  'condizente',
#  'desumana',
#  'expurgar',
#  'cinquentenária',
#  'Dinamica',
#  'Oferece',
#  'sextas',
#  'esfihas',
#  'petiscos',
#  'berbigões',
#  'amêijoas',
#  'toparam',
#  'Oldman',
#  'improvável',
#  'rastafari',
#  'Brad',
#  'hippie',
#  'vianjandão',
#  'Rubinek',
#  'Rapaport',
#  'precisei',
#  'Explosão',
#  'lotada',
#  'Trípoli',
#  'patrulhada',
#  'Zangam-se',
#  'convidando-os',
#  'extraordinariamente',
#  'Visitou',
#  'Jacopo',
#  'Barbari',
#  'Usuarios',
#  'Marilda',
#  'Ginez',
#  'amp',
#  'lavam',
#  'escolhiam',
#  'cabrita',
#  'COMISSAO',
#  'MEC-SESU',
#  'postulados',
#  'aspirado',
#  'emocionado',
#  'reviver',
#  'germânico',
#  'nata',
#  'auto-excluiu-se',
#  'extremosamente',
#  'deu-te',
#  'perder-te',
#  'conservar-te',
#  'pecuário',
#  'caprinos',
#  'Sampa',
#  'Happy-End',
#  'legislado',
#  'lei-quadro',
#  'Trebbiano',
#  'pormenorizado',
#  'abreviar',
#  'Secundaria',
#  'Reconhecendo',
#  'Piero',
#  'Verrocchio',
#  'encantatórios',
#  'mágicos',
#  'GUILHERME',
#  'CALDAS',
#  'EMRICH',
#  'Arktikum',
#  'Nafta',
#  'ingresso',
#  'Exclusividade',
#  'DETENDER',
#  '959',
#  'Somague',
#  'programadas',
#  'fixei',
#  'Radical',
#  'Vinhaça',
#  'Componentes',
#  'shtml',
#  'Disbelief',
#  'hard.feeli.shtml',
#  'It.s.2001',
#  'but.racism.shtml',
#  '021901',
#  'Governor.s.rating.dro.shtml',
#  'desqualificar',
#  'condenando',
#  'formalismo',
#  'brilhantismo',
#  'Vittorio',
#  'Mosele',
#  'Saverio',
#  'Revolucionária',
#  'Unida',
#  'FRU',
#  'especificou',
#  'superíficies',
#  'acoisa',
#  'Ohdiabo',
#  'baila',
#  'rejeitando',
#  'Poder-se-ia',
#  '24hs',
#  'Aluga-se',
#  'ALÁrea',
#  'lazerA',
#  'praiaA',
#  'Vi-lhe',
#  'tirá-los',
#  'amuado',
#  'chorada',
#  'motivaram',
#  'Muinicipal',
#  'admira-se',
#  'Tyrrenika',
#  'infindável',
#  'anedotário',
#  'etrusco',
#  '168',
#  'semanários',
#  'Clarim',
#  'programou',
#  'puser',
#  'doseada',
#  'Produtividade',
#  'Policiais-Militares',
#  'Rapidinhas',
#  'éacusado',
#  'pênis',
#  'portava',
#  'xenofobia',
#  'Pega-me',
#  'camisola',
#  'leva-me',
#  'assembléia',
#  'acusou-o',
#  'cimentado',
#  'ínfimo',
#  'desembarcamos',
#  'Discovery',
#  'reparado',
#  'Greg',
#  'Harbaugh',
#  'Tanner',
#  'actualizar',
#  'aprestamento',
#  'Calisto',
#  'épossível',
#  'englobam',
#  'miradouro',
#  'Toulouse',
#  '4-1',
#  'amam',
#  'desmentidos',
#  'malvada',
#  'agroindústria',
#  'joint-ventures',
#  '12.10.2000',
#  'Incomodava-o',
#  'ocultar',
#  'Achei-a',
#  'inicializou',
#  'Pensa-se',
#  'tatuarem',
#  'Ficarei',
#  'fracasse',
#  'pilhas',
#  'palito',
#  '1642-54-61',
#  'proporem',
#  'depravadas',
#  'nº24',
#  'mal-entendidos',
#  'sócio-económicos',
#  'Roma-Florença-Veneza',
#  'provisórias',
#  'Bienais',
#  '1.236',
#  'dissolvido',
#  'Yolanda',
#  'importantíssimo',
#  'Auto-Retrato',
#  'presenteados',
#  'Foram-se',
#  'frenético',
#  'manipularam-se',
#  '3,2',
#  'Mestrinho',
#  'Pintcha',
#  'pulos',
#  'defuntas',
#  'Union',
#  'Pré',
#  'ProtoHistoriques',
#  'UISPP',
#  'Gigi',
#  'vencida',
#  'Fiorentina',
#  'Serena',
#  'tristura',
#  'iluminar',
#  'Albinante',
#  'Oromar',
#  'weekend',
#  'grandíssimo',
#  'enaltecer',
#  'hesitou',
#  'constrói-se',
#  'admiradouro',
#  'Pesquisador',
#  'Avançados',
#  'convoco',
#  'ACADÉMICO',
#  'BASKET',
#  'CLUBE',
#  'Complexo',
#  'querer-me',
#  'Consideremos',
#  'paradigmática',
#  'delimitar',
#  'contornos',
#  'contextualmente',
#  'aproximam',
#  'Laginha',
#  'Burmester',
#  'Eunice',
#  'Muñoz',
#  '94,9',
#  'cablagens',
#  'Acrescentamos',
#  'privilegiam',
#  'paralelepípedos',
#  'graminha',
#  'vãozinho',
#  'plépléplé',
#  'inteirinha',
#  '418',
#  'C5-0345',
#  '-2001',
#  '0166',
#  'Cooperfat',
#  'Centramos',
#  'pontualidade',
#  'certificamos',
#  'CEP.1485',
#  'indivisíveis',
#  'manilhas',
#  'PréHistória',
#  'Arqueólogos',
#  'actualizados',
#  'CRP',
#  'Trás-os-Montes',
#  'quantitativas',
#  'insónias',
#  'qualitativas',
#  'descansado',
#  'reparador',
#  'FIQUE',
#  'OLHO',
#  'fixámos',
#  'madrilena',
#  'obrigacionistas',
#  'compensaram',
#  'sustos',
#  'Lebed',
#  'stressante',
#  'IGAPHE',
#  'Gaudêncio',
#  'colos',
#  'desvergonha',
#  'arregalarmos',
#  'desviarmos',
#  'referir-me',
#  'precipitasse',
#  'funda',
#  'espedaçasse',
#  'venenosos',
#  'enchiam',
#  'grotas',
#  'alcantis',
#  'ambiciosas',
#  'coabitação',
#  'pág.',
#  'escrivão',
#  'penitenciária',
#  'contraiu',
#  'núpcia',
#  'Eugênio',
#  'Perguntando',
#  'énecessário',
#  'penúltimo',
#  'fumei',
#  'tosses',
#  'largarem',
#  'maldito',
#  'Detector',
#  'Dependendo',
#  'astrofísico',
#  'culminará',
#  'Pranto',
#  'Parda',
#  'recepcionista',
#  'Patrulhas',
#  'delegadas',
#  'Glass',
#  'SOLENE',
#  'ABRE',
#  'LECTIVO',
#  'unam',
#  'paroquiais',
#  'astronômicos',
#  'transportadora',
#  'Rabaneda',
#  'fragilidade',
#  'atingidas',
#  'platéia',
#  'excelências',
#  'ó',
#  'adulação',
#  'Bombardeio',
#  'generalização',
#  'urbanística',
#  'submissos',
#  'detectavam',
#  'ci.htm',
#  'emoçao',
#  'corada',
#  'qui-la',
#  'conjectura',
#  'mormente',
#  'matadores',
#  'fotografar',
#  'segurando',
#  'isolar-se',
#  'sociável',
#  'inspeções',
#  'amostragens',
#  'dirigirmos',
#  'enérgicos',
#  'disponibilizando',
#  'Tens-me',
#  'Dobb',
#  'Mercedes-Benz',
#  'Ato',
#  'anti-governo',
#  'Condições',
#  'Frota',
#  'Consulta',
#  'CONDIÇÕES',
#  'USADOS',
#  'VENDA',
#  'recuada',
#  'olímpicos',
#  '6-8',
#  'Philippe',
#  'Moureaux',
#  'ex-vice-primeiro-ministro',
#  'entregou-me',
#  'omnipotência',
#  'milagrosas',
#  'obram',
#  'Caudais',
#  'Vazão',
#  'acordou-se',
#  'preparasse',
#  'vincava',
#  'divulgava',
#  'implosão',
#  'helvética',
#  'Conta-se',
#  'Ursula',
#  'Lancaster',
#  'Lencastre',
#  'sinteticamente',
#  '122',
#  'inerte',
#  'lionísticos',
#  'angariados',
#  'D.Francisco',
#  'Rapazes',
#  'Paralisia',
#  'Cerebral',
#  'cara-dura',
#  'verdinho',
#  'fusível',
#  'rogava',
#  'cingia',
#  'arrancá-lo',
#  'orte',
#  'arrostava',
#  'adivinharia',
#  '44,16',
#  'candidadutar',
#  'leccionou',
#  'pô-los',
#  'DESPORTIVOS',
#  'Compadre',
#  'Anedotas',
#  'Fragrâncias',
#  'incapacitante',
#  'costureiros',
#  'colaborou',
#  'ADRAL',
#  'pré-venda',
#  'sublinha-se',
#  'atropelos',
#  'atrito',
#  'comunico-vos',
#  '2003-02-20',
#  '12H11',
#  'chame',
#  'assessorar',
#  '1,81',
#  '5.5',
#  'Afluências',
#  'Volumes',
#  'Cantei',
#  'tecnicismo',
#  'adiantemos',
#  'Lowell',
#  'Lote',
#  'Qtd.de',
#  'Beisebol',
#  'Softbol',
#  'nikkeys',
#  'Despromovido',
#  'provavam',
#  'lançavam',
#  'Aggressive',
#  'ganharem',
#  'actualizarem',
#  'congratulado',
#  'ognísitca',
#  'combinava-se',
#  'honestos',
#  'inexpugnável',
#  'bastiões',
#  'mouriscos',
#  'subjugados',
#  '1485',
#  'León',
#  'Tambem',
#  'ultrapassaram',
#  'alteraram-se',
#  'Nulo',
#  'Nihonline.com.br',
#  'Escherichia',
#  'coli',
#  'microorganismo',
#  'clonagem',
#  'narrador',
#  'perverso',
#  'agonizante',
#  'prestaram',
#  'levando-o',
#  'Midlej',
#  'BRs',
#  '040',
#  '383',
#  'neonazis',
#  'insultando',
#  'embasbacado',
#  'verificando',
#  'traçámos',
#  'encaravam',
#  'contribuiria',
#  'anti-castristas',
#  'encaminhando',
#  'cabeceiras',
#  'Erosões',
#  '--Mana',
#  'tamanhão',
#  'mansa',
#  'Daria',
#  'amarguradas',
#  'amargura',
#  'Salário',
#  'profisional',
#  'otimizando',
#  'áerea',
#  'conjugo',
#  'controladas',
#  'reparamos',
#  'reagiam',
#  'reprimido',
#  'vinil',
#  'julgasse',
#  'causasse',
#  'empanasse',
#  'secos',
#  'Sahara',
#  'Jesuzinho',
#  'empalhado',
#  'embrulhadinho',
#  'nuns',
#  'infundados',
#  'despercebidos',
#  'sumiu',
#  'ok',
#  'Ibero',
#  'intalações',
#  'oásis',
#  'Taquara',
#  'postais',
#  'Euronotícias',
#  'semanário',
#  'redactorial',
#  'RER',
#  'preenche',
#  'Nissl',
#  'PUBERDADE',
#  'Inscreva-se',
#  'Ministrou',
#  'Extensao',
#  'Tecnologica',
#  'aportuguesada',
#  'Bundesland',
#  'Renânia',
#  'Norte-Vestfália',
#  'Hyperfocal',
#  'Ditadura',
#  'dizíamos',
#  'conseguiram-se',
#  'intuição',
#  'ondulatória',
#  '11.250',
#  '14.700',
#  '54.900',
#  'soltou-se',
#  'olhou-o',
#  'impetrou',
#  'desobrigar-se',
#  'instituído',
#  'Suco',
#  'Femino',
#  'Alberta',
#  'Ferreti',
#  'Montegridolfo',
#  'sobrecarregado',
#  'difuso',
#  'postergar',
#  'Abravest',
#  '23.000',
#  '4.120',
#  '1200',
#  'adulto-infantil',
#  'transistores',
#  'tiristorizada',
#  'Barrosão',
#  'SITES',
#  'VISITADOS',
#  'www.badbrasil.hpg.com.br',
#  'www.uol.com.br',
#  'aureliomiguel',
#  'www.cnnsi.com',
#  '6o',
#  'certidões',
#  'traslados',
#  'produzirão',
#  'conciliatório',
#  'encarando-as',
#  'Inspector-Geral',
#  'jumento',
#  'orientar-nos',
#  'Mundos',
#  'Enlouquecida',
#  'vasculha',
#  'goverrno',
#  'baseiam-se',
#  'Escavações',
#  'Almóada',
#  'Califal',
#  'Taifas',
#  'recolhido',
#  'integrarão',
#  'PRISCILA',
#  'SÉRVULO',
#  'fechar-nos',
#  'obrigar-nos',
#  'Viúva',
#  'devota',
#  'temente',
#  'buscou',
#  'confiando',
#  'transferiu',
#  'colmatar',
#  'interviesse',
#  'refundado',
#  'Itanhaém',
#  'Mongaguá',
#  'Abrimo-lo',
#  'abri-lo',
#  'forum',
#  'hiatos',
#  'pares-bases',
#  'noticiar',
#  'Haliembra',
#  '2A',
#  'plissada',
#  'Bady',
#  'Saad',
#  'pagode',
#  'ocultando',
#  'idiota',
#  ...]

# %%
currency_pattern = r"\b(?<![.,-])[0-9]{1,3}(?:,?[0-9]{3})*\.[0-9]{2}(?![.,-])\b|\b(?<![.,-])[0-9]{1,3}(?:.?[0-9]{3})*\,[0-9]{2}(?![.,-])\b"

# %%
valores = [singleton for singleton in singletons if re.match(pattern=currency_pattern, string=singleton)]
print(len(valores))
valores
# Out:
# 183
# ['2,02',
#  '3,41',
#  '310,00',
#  '44,16',
#  '1,81',
#  '1.368,23',
#  '12,07',
#  '11,00',
#  '78,00',
#  '0,30',
#  '0,40',
#  '0,70',
#  '2.409,66',
#  '21,00',
#  '2,99',
#  '2.694,218,00',
#  '56,00',
#  '66,00',
#  '2.176,26',
#  '3.00',
#  '51.569,30',
#  '61,87',
#  '62,84',
#  '63,09',
#  '73,22',
#  '48,16',
#  '89,00',
#  '80.000,00',
#  '55,20',
#  '44,00',
#  '55,00',
#  '2,30',
#  '3,12',
#  '7,90',
#  '2,75',
#  '0.10',
#  '0.20',
#  '0.50',
#  '54,00',
#  '25,00',
#  '25,90',
#  '1,60',
#  '81,00',
#  '13,56',
#  '63,70',
#  '72,00',
#  '0,55',
#  '2,05',
#  '376,82',
#  '456,00',
#  '74,00',
#  '51,00',
#  '175.50',
#  '147.50',
#  '57,00',
#  '4,49',
#  '0,71',
#  '29,30',
#  '68,00',
#  '368,00',
#  '23,00',
#  '148.00',
#  '49.879,79',
#  '33,53',
#  '5,30',
#  '2,54',
#  '5,36',
#  '428,00',
#  '376,00',
#  '4,51',
#  '285,00',
#  '196,00',
#  '0,20',
#  '630,00',
#  '73,60',
#  '63,00',
#  '100,00',
#  '33,00',
#  '862,00',
#  '288,00',
#  '287,00',
#  '49,99',
#  '1.921.598,00',
#  '8666,91',
#  '12.00',
#  '592.00',
#  '39,00',
#  '59,00',
#  '129,00',
#  '1,40',
#  '175,00',
#  '292,00',
#  '68.00',
#  '118.00',
#  '300.000,00',
#  '1.000,00',
#  '2.000,00',
#  '102,35',
#  '102,36',
#  '0800.14',
#  '28,10',
#  '37,90',
#  '29,90',
#  '189,00',
#  '4.300,00',
#  '2,47',
#  '5481,61',
#  '0,01',
#  '3,76',
#  '3,71',
#  '6.75',
#  '29,99',
#  '5.75',
#  '27.03',
#  '10.04',
#  '5,90',
#  '58,00',
#  '9.30',
#  '0.01',
#  '0.02',
#  '0.05',
#  '173.00',
#  '82,00',
#  '598,494,00',
#  '50,00',
#  '15,00',
#  '3,25',
#  '315,00',
#  '4.07',
#  '6,70',
#  '270,50',
#  '7.481,97',
#  '6,05',
#  '27,05',
#  '51,11',
#  '500,00',
#  '405.00',
#  '35,90',
#  '772,80',
#  '01.94',
#  '1,75',
#  '153.00',
#  '0,25',
#  '52,00',
#  '0,02',
#  '820,00',
#  '100.000,00',
#  '6,27',
#  '62,16',
#  '290,00',
#  '259.00',
#  '0,85',
#  '0,04',
#  '140.00',
#  '69,69',
#  '90,00',
#  '18,25',
#  '18,00',
#  '444,00',
#  '1,79',
#  '399,00',
#  '58,88',
#  '145.00',
#  '0,62',
#  '29,00',
#  '99,27',
#  '38,50',
#  '164.00',
#  '5,25',
#  '4,90',
#  '276,00',
#  '42,00',
#  '185,00',
#  '160,00',
#  '55.11',
#  '190,00',
#  '30,99',
#  '43,68',
#  '5,88',
#  '100,46',
#  '19,99',
#  '709,80',
#  '18,11']
