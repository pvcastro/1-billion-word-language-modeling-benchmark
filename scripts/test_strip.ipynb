# %%
import codecs

# %%
for line in codecs.open('/media/discoD/Corpora/Portuguese Wikipedia Dump/wiki_filtered.sorted.txt', 'r', 'utf-8'):
    print(line)
# Out:
# ´
#
# `
#
# ~
#
# <
#
# <!--
#
# <!--
#
# <!-- ==
#
# ≤
#
# =
#
# ==
#
# |
#
# |-
#
# |}
#
# |}
#
#
#
#  ^
#
#  ÷
#
#  |
#
#  |-
#
#
#
#
#
#  --  --  --
#
#  -----
#
#  , , , , , ,
#
#  ;
#
#  ; ; ; .
#
#  := ;
#
#  /
#
#  /
#
#  / "
#
#  .
#
#  .
#
#  '
#
#  "
#
#  "
#
#  )
#
#  };
#
#  +----------------------------+----------------------------+--------------------------------------------------
#
#  +---------+----+--------------------+
#
#  ⋈
#
# _
#
# __
#
# __ _*(#(#(
#
# ___
#
# ____
#
# _____
#
# _______
#
# ________
#
# _________
#
# ____________
#
# ____________________
#
# ______________________
#
# _______________________
#
# ________________________
#
# ________________________ . ________________________
#
# _________________________
#
# __________________________
#
# _____________________________
#
# ______________________________
#
# __________________________________
#
# ___________________________________
#
# ____________________________________
#
# ...

# %%
for line in codecs.open('/media/discoD/Corpora/Portuguese Wikipedia Dump/wiki_filtered.sorted.clean.txt', 'r', 'utf-8'):
    print(line)
# Out:
# ´
#
# `
#
# ~
#
# <
#
# <!--
#
# <!--
#
# <!-- ==
#
# ≤
#
# =
#
# ==
#
# |
#
# |-
#
# |}
#
# |}
#
#
#
#  ^
#
#  ÷
#
#  |
#
#  |-
#
#
#
#
#
#  --  --  --
#
#  -----
#
#  , , , , , ,
#
#  ;
#
#  ; ; ; .
#
#  := ;
#
#  /
#
#  /
#
#  / "
#
#  .
#
#  .
#
#  '
#
#  "
#
#  "
#
#  )
#
#  };
#
#  +----------------------------+----------------------------+--------------------------------------------------
#
#  +---------+----+--------------------+
#
#  ⋈
#
# _
#
# __
#
# __ _*(#(#(
#
# ___
#
# ____
#
# _____
#
# _______
#
# ________
#
# _________
#
# ____________
#
# ____________________
#
# ______________________
#
# _______________________
#
# ________________________
#
# ________________________ . ________________________
#
# _________________________
#
# __________________________
#
# _____________________________
#
# ______________________________
#
# __________________________________
#
# ___________________________________
#
# ____________________________________
#
# ...
